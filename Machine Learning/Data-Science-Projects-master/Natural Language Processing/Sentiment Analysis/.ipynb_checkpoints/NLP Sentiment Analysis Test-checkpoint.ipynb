# %% [markdown]
# # NLP Sentiment Analysis Test

# %%
import nltk

# %%
# Tokenisation
from nltk.tokenize import word_tokenize,sent_tokenize

#tokenized = word_tokenize(text)

# Stop Words
import string
from nltk.corpus import stopwords
def stop_words(tokenized):
    punctuation = list(string.punctuation) #['.',',',':',';','?','!']
    stop_words = list(stopwords.words("english"))
    #stop_words = ['a','as','at','they','the','his','her','so','and','were','from',
    #              'that','of','in','only','with','to']
    included_punctuation = [word for word in tokenized 
                            if word.lower() in punctuation]
    included_stop_words = [word for word in tokenized 
                           if word.lower() in stop_words]
    everything_else = [word for word in tokenized 
                       if word.lower() not in set(stop_words + punctuation)]
    return everything_else,included_stop_words,included_punctuation

# Stemming and Lemming
from nltk.stem import PorterStemmer, LancasterStemmer
def stemlem(tokenized):
    stemmer = PorterStemmer()
    lemmatizer = nltk.WordNetLemmatizer()
    return [ [w,stemmer.stem(w),lemmatizer.lemmatize(w)] 
    for w in list(set(tokenized))]
    
# POS Tagging
def pos_tagging(tokenized):
    tagged =  nltk.pos_tag(list(set(tokenized)))
    tagged = [(t[0],t[1]) for t in tagged]
    return tagged

# Bi/Trigrams
from nltk import bigrams, trigrams
def grams(tokenized):
    return list(bigrams(tokenized)), list(trigrams(stop_words(tokenized)[0]))
    
# Frequency related statistics
from collections import Counter
import math
def frequency_statistics(text):
    words = word_tokenize(text)
    # Organisation
    words = list(set(stop_words(words)[0])) +\
    list(set(stop_words(words)[1])) +\
    list(set(stop_words(words)[2]))
    sents = sent_tokenize(text) 
    #filtered = stop_words(words)
    tf= {word:Counter(word_tokenize(text))[word] for word in words} #Term Frequency
    df = {}
    for word in words:
        df[word] = 0
        for sent in sents:
            if word in sent: df[word]+=1
    idf = {word: math.log(len(sent)/df,10) for (word, df) in  df.items()}
    tfidf = {word: tf[word]*idf[word] for word in words}
    #Processing
    stats = []
    for word in words:
        stats += [[word,tf[word],df[word],idf[word],tfidf[word]]]
    return stats

# %%
from nltk.corpus import movie_reviews
lemmatizer = nltk.WordNetLemmatizer()
'''
documents = [(list(movie_reviews.words(fileid)), category)
            for category in movie_reviews.categories()
            for fileid in movie_reviews.fileids(category)]
'''
documents = [(list(movie_reviews.words(fileid)), category)
            for category in movie_reviews.categories()
            for fileid in movie_reviews.fileids(category)]

import random
random.shuffle(documents)

# %%
all_words = []
for w in movie_reviews.words():
  all_words.append(w.lower())

# %% [markdown]
# Import Data

# %%
import pandas as pd
df = pd.read_csv("NewsSentiments.csv")

from nltk.corpus import stopwords
stop_words = list(stopwords.words("english"))
import re
def lower(words):
    #print(words)
    return [word.lower() for word in words 
            if #not bool(re.match(r"0-9",word)) or 
            word not in stop_words ]
from nltk import word_tokenize
documents = [(lower(word_tokenize(df.iloc[i]["Text"])),df.iloc[i]["Sentiments"])
            for i in df.index.values]
import random
random.shuffle(documents)

# %%
import re
bool(re.match("\d","500,000"))
documents
# Out:
# [(['foote',
#    'mineral',
#    '&',
#    'lt',
#    ';',
#    'fte',
#    '>',
#    'sells',
#    'cambridge',
#    'plant',
#    'foote',
#    'mineral',
#    'co',
#    'said',
#    'signed',
#    'letter',
#    'intent',
#    'shieldalloy',
#    'corp',
#    ',',
#    'wholly-owned',
#    'subsidiary',
#    '&',
#    'lt',
#    ';',
#    'metallurg',
#    'inc',
#    '>',
#    ',',
#    'sale',
#    'cambridge',
#    ',',
#    'ohio',
#    ',',
#    'business',
#    '.',
#    'the',
#    'company',
#    'said',
#    'sale',
#    ',',
#    'explained',
#    'greater',
#    'detail',
#    'definitive',
#    'agreement',
#    'signed',
#    ',',
#    'part',
#    'foote',
#    "'s",
#    'previously-announced',
#    'plan',
#    'sell',
#    'entire',
#    'company',
#    '.'],
#   1),
#  (['cantrex',
#    'unit',
#    'to',
#    'merge',
#    'with',
#    'ontario',
#    'group',
#    '(',
#    'groupe',
#    'cantrex',
#    'inc',
#    ')',
#    'said',
#    'plans',
#    'merge',
#    'new',
#    'wholly-owned',
#    'subsidiary',
#    'merger',
#    'agreement',
#    '(',
#    'cap',
#    'appliance',
#    'purchasers',
#    'inc',
#    ')',
#    ',',
#    'woodstock',
#    ',',
#    'ontario',
#    ',',
#    'group',
#    '400',
#    'appliance',
#    'electronics',
#    'retailers',
#    '.',
#    'it',
#    'said',
#    'cap',
#    'shareholders',
#    'receive',
#    '140,700',
#    'first',
#    'preferred',
#    'groupe',
#    'cantrex',
#    'shares',
#    'entitling',
#    'holders',
#    'receive',
#    '6.05',
#    'dlrs',
#    'per',
#    'share',
#    'equivilant',
#    'class',
#    'a',
#    'subordinate',
#    'voting',
#    'cantrex',
#    'shares',
#    '.',
#    'the',
#    'merger',
#    'effective',
#    'april',
#    'one',
#    'subject',
#    'shareholder',
#    'approval',
#    '.'],
#   1),
#  (['handy',
#    'and',
#    'harman',
#    '&',
#    'lt',
#    ';',
#    'hnh',
#    '>',
#    '4th',
#    'qtr',
#    'loss',
#    'shr',
#    'loss',
#    '51',
#    'cts',
#    'vs',
#    'loss',
#    'three',
#    'cts',
#    'net',
#    'loss',
#    '7,041,000',
#    'vs',
#    'loss',
#    '467,000',
#    'rev',
#    '138.9',
#    'mln',
#    'vs',
#    '131.4',
#    'mln',
#    '12',
#    'months',
#    'shr',
#    'loss',
#    '64',
#    'cts',
#    'vs',
#    'profit',
#    '46',
#    'cts',
#    'net',
#    'loss',
#    '8,843,000',
#    'vs',
#    'profit',
#    '6,306,0000',
#    'rev',
#    '558.9',
#    'mln',
#    'vs',
#    '556.7',
#    'mln',
#    'note',
#    ':',
#    'net',
#    'loss',
#    '4th',
#    'qtr',
#    '1986',
#    'includes',
#    'charge',
#    'restructuring',
#    '2.6',
#    'mln',
#    'dlrs',
#    'tax',
#    ',',
#    '19',
#    'cts',
#    'share',
#    '.',
#    '1986',
#    'net',
#    'loss',
#    'includes',
#    'tax',
#    'special',
#    'charge',
#    '2.7',
#    'mln',
#    'dlrs',
#    ',',
#    '20',
#    'cts',
#    'share',
#    '.'],
#   1),
#  (['northern',
#    'telecom',
#    'ltd',
#    '&',
#    'lt',
#    ';',
#    'nt',
#    '>',
#    'declares',
#    'stock',
#    'split',
#    'two-for-one',
#    'stock',
#    'split',
#    'pay',
#    'may',
#    '12',
#    'note',
#    ':',
#    'split',
#    'subject',
#    'approval',
#    'shareholders',
#    'april',
#    '23',
#    'annual',
#    'meeting',
#    '.',
#    'company',
#    'also',
#    'said',
#    'increase',
#    'dividend',
#    'post-split',
#    'shares',
#    'six',
#    'cts',
#    'five',
#    'cts',
#    '.'],
#   -1),
#  (['api',
#    'says',
#    'distillate',
#    'stocks',
#    'off',
#    '4.4',
#    'mln',
#    'bbls',
#    ',',
#    'gasoline',
#    'off',
#    '30,000',
#    ',',
#    'crude',
#    'up',
#    '700,000',
#    'api',
#    'says',
#    'distillate',
#    'stocks',
#    'off',
#    '4.4',
#    'mln',
#    'bbls',
#    ',',
#    'gasoline',
#    'off',
#    '30,000',
#    ',',
#    'crude',
#    'up',
#    '700,000'],
#   -1),
#  (['united',
#    'presidential',
#    'corp',
#    '&',
#    'lt',
#    ';',
#    'upco',
#    '>',
#    '4th',
#    'qtr',
#    'net',
#    'shr',
#    '39',
#    'cts',
#    'vs',
#    '50',
#    'cts',
#    'net',
#    '1,545,160',
#    'vs',
#    '2,188,933',
#    'revs',
#    '25.2',
#    'mln',
#    'vs',
#    '19.5',
#    'mln',
#    'year',
#    'shr',
#    '1.53',
#    'dlrs',
#    'vs',
#    '1.21',
#    'dlrs',
#    'net',
#    '6,635,318',
#    'vs',
#    '5,050,044',
#    'revs',
#    '92.2',
#    'mln',
#    'vs',
#    '77.4',
#    'mln',
#    'note',
#    ':',
#    'results',
#    'include',
#    'adjustment',
#    '848,600',
#    'dlrs',
#    '20',
#    'cts',
#    'shr',
#    '1986',
#    'year',
#    '1985',
#    'periods',
#    'improvement',
#    'results',
#    'universal',
#    'life',
#    'business',
#    'first',
#    'estimated',
#    '.'],
#   0),
#  (['ivaco',
#    'sees',
#    'minimal',
#    'first',
#    'quarter',
#    'earnings',
#    '(',
#    'ivaco',
#    'inc',
#    ')',
#    'said',
#    'price',
#    'pressure',
#    'steel',
#    'products',
#    ',',
#    'particularly',
#    'u.s.',
#    ',',
#    'recent',
#    'increase',
#    'value',
#    'canadian',
#    'dollar',
#    'expected',
#    'result',
#    '``',
#    'minimal',
#    "''",
#    'first',
#    'quarter',
#    'earnings',
#    '.',
#    'it',
#    'said',
#    'subsequent',
#    'quarters',
#    'show',
#    'substantial',
#    'improvement',
#    'first',
#    'quarter',
#    'levels',
#    '1987',
#    'earnings',
#    'reach',
#    '1986',
#    'levels',
#    'long',
#    'conditions',
#    'continue',
#    '.',
#    'ivaco',
#    'earlier',
#    'reported',
#    '1986',
#    'profit',
#    'rose',
#    '44.1',
#    'mln',
#    'dlrs',
#    ',',
#    'one',
#    'mln',
#    'dlr',
#    'extraordinary',
#    'gain',
#    ',',
#    '35.1',
#    'mln',
#    'dlrs',
#    'previous',
#    'year',
#    '.',
#    'it',
#    'said',
#    'demand',
#    'company',
#    "'s",
#    'products',
#    'continuing',
#    'high',
#    'levels',
#    'sales',
#    'expected',
#    'show',
#    'growth',
#    '.',
#    'revenues',
#    'last',
#    'year',
#    'rose',
#    '1.94',
#    'billion',
#    'dlrs',
#    '1.34',
#    'billion',
#    'dlrs',
#    '1985',
#    '.'],
#   0),
#  (['piedmont',
#    'aviation',
#    '&',
#    'lt',
#    ';',
#    'pie',
#    '>',
#    'board',
#    'to',
#    'meet',
#    'today',
#    'piedmont',
#    'avaition',
#    'inc',
#    "'s",
#    'board',
#    'directors',
#    'conduct',
#    'special',
#    'meeting',
#    'beginning',
#    '1400',
#    'est',
#    'today',
#    ',',
#    'piedmont',
#    'spokesman',
#    'said',
#    '.',
#    'the',
#    'spokesman',
#    'would',
#    'say',
#    'agenda',
#    '.',
#    'in',
#    'mid-february',
#    ',',
#    'piedmont',
#    'said',
#    'board',
#    'would',
#    'meet',
#    'discuss',
#    'proposals',
#    'acquire',
#    'company',
#    '.',
#    'its',
#    'board',
#    'also',
#    'withdrew',
#    'recommendation',
#    'accept',
#    '65',
#    'dlrs',
#    'share',
#    'cash',
#    'offer',
#    'norfolk',
#    'southern',
#    'corp',
#    '&',
#    'lt',
#    ';',
#    'nsc',
#    '>',
#    'light',
#    'competing',
#    'revised',
#    'bid',
#    'u.s.',
#    'air',
#    'group',
#    'inc',
#    '&',
#    'lt',
#    ';',
#    'u',
#    '>',
#    '.',
#    'u.s.',
#    'air',
#    'offer',
#    'buy',
#    '50',
#    'pct',
#    'company',
#    "'s",
#    'stock',
#    '71',
#    'dlrs',
#    'share',
#    'cash',
#    ',',
#    'remaining',
#    '73',
#    'dlrs',
#    'share',
#    'stock',
#    '.'],
#   1),
#  (['calmar',
#    '&',
#    'lt',
#    ';',
#    'clmi',
#    '>',
#    'seeks',
#    'to',
#    'be',
#    'acquired',
#    'by',
#    '&',
#    'lt',
#    ';',
#    'kebo',
#    'ab',
#    '>',
#    'calmar',
#    'inc',
#    'said',
#    'keboo',
#    'ab',
#    'sweden',
#    ',',
#    'owns',
#    '64',
#    'pct',
#    'calmark',
#    ',',
#    'approved',
#    'acquisition',
#    'remaining',
#    'calmar',
#    'shares',
#    '25.375',
#    'dlrs',
#    'cash',
#    'request',
#    'calmar',
#    'board',
#    '.',
#    'calmar',
#    'said',
#    'special',
#    'meeting',
#    'board',
#    'held',
#    'march',
#    'nine',
#    'form',
#    'special',
#    'committee',
#    'directors',
#    'affiliated',
#    'kebo',
#    'evaluate',
#    'transaction',
#    '.',
#    'kebo',
#    'turn',
#    '60',
#    'pct',
#    'owned',
#    '&',
#    'lt',
#    ';',
#    'investment',
#    'ab',
#    'beijar',
#    '>',
#    'sweden',
#    '.'],
#   1),
#  (['26-feb-1987', '26-feb-1987'], 0),
#  (['wallace',
#    'computer',
#    'services',
#    'inc',
#    '&',
#    'lt',
#    ';',
#    'wcs',
#    '>',
#    'dividend',
#    'qtly',
#    'div',
#    '15',
#    'cts',
#    'vs',
#    '15',
#    'cts',
#    'previously',
#    'pay',
#    'june',
#    '19',
#    'record',
#    'june',
#    'one'],
#   -1),
#  (['philippine',
#    'long',
#    'distance',
#    '&',
#    'lt',
#    ';',
#    'phi',
#    '>',
#    'year',
#    'net',
#    'shr',
#    'primary',
#    '95.30',
#    'pesos',
#    'vs',
#    '29.71',
#    'pesos',
#    'shr',
#    'diluted',
#    '61.11',
#    'pesos',
#    'vs',
#    '18.49',
#    'pesos',
#    'qtly',
#    'div',
#    '1.25',
#    'pesos',
#    'vs',
#    '1.25',
#    'pesos',
#    'net',
#    '1.9',
#    'billion',
#    'vs',
#    '779',
#    'mln',
#    'revs',
#    '6.1',
#    'billion',
#    'vs',
#    '4.7',
#    'billion',
#    'note',
#    ':',
#    'full',
#    'name',
#    'philippine',
#    'long',
#    'distance',
#    'telephone',
#    'co',
#    '.',
#    'figures',
#    'quoted',
#    'philippine',
#    'pesos',
#    '.',
#    'dividend',
#    'payable',
#    'april',
#    '15',
#    'holders',
#    'record',
#    'march',
#    '13',
#    '.',
#    'exchange',
#    'rate',
#    'day',
#    'dividend',
#    'declaration',
#    '20.792',
#    'pesos',
#    'per',
#    'dollar',
#    '.'],
#   0),
#  (['scott',
#    "'s",
#    'hospitality',
#    'acquires',
#    'capital',
#    'food',
#    '&',
#    'lt',
#    ';',
#    'scott',
#    "'s",
#    'hospitality',
#    'inc',
#    '>',
#    'said',
#    'acquired',
#    'issued',
#    'shares',
#    'capital',
#    'food',
#    'services',
#    'ltd',
#    ',',
#    'ottawa',
#    '.',
#    'terms',
#    'disclosed',
#    '.',
#    'scott',
#    "'s",
#    'said',
#    'capital',
#    'food',
#    '1986',
#    'sales',
#    '20',
#    'mln',
#    'dlrs',
#    'continue',
#    'operate',
#    'present',
#    'name',
#    'existing',
#    'management',
#    '.',
#    'capital',
#    'food',
#    'provides',
#    'food',
#    'services',
#    'several',
#    'ottawa',
#    'institutions',
#    ',',
#    'company',
#    'said',
#    '.'],
#   1),
#  (['alatenn',
#    'resources',
#    'inc',
#    '&',
#    'lt',
#    ';',
#    'atng',
#    '>',
#    '4th',
#    'qtr',
#    'net',
#    'shr',
#    '75',
#    'cts',
#    'vs',
#    '52',
#    'cts',
#    'net',
#    '1,699,124',
#    'vs',
#    '1,177,786',
#    'revs',
#    '45.6',
#    'mln',
#    'vs',
#    '31.6',
#    'mln',
#    '12',
#    'mths',
#    'shr',
#    '2.22',
#    'dlrs',
#    'vs',
#    '2.20',
#    'dlrs',
#    'net',
#    '5,057,292',
#    'vs',
#    '4,961,085',
#    'revs',
#    '130.2',
#    'mln',
#    'vs',
#    '126.7',
#    'mln'],
#   0),
#  (['malaysia',
#    're-imposes',
#    'export',
#    'duties',
#    'on',
#    'rubber',
#    'the',
#    'malaysian',
#    'government',
#    'said',
#    're-imposed',
#    'export',
#    'duties',
#    'rubber',
#    '3/8',
#    'cent',
#    'per',
#    'kilo',
#    'gazetted',
#    'price',
#    'moved',
#    'threshold',
#    'price',
#    '210',
#    'cents',
#    'per',
#    'kilo',
#    '.',
#    'the',
#    'gazetted',
#    'price',
#    ',',
#    'effective',
#    'march',
#    '1',
#    ',',
#    'rose',
#    '213-1/2',
#    'cents',
#    'per',
#    'kilo',
#    'february',
#    "'s",
#    '207',
#    '.',
#    'the',
#    'duty',
#    'research',
#    'remains',
#    '3.85',
#    'cents',
#    'per',
#    'kilo',
#    'replanting',
#    'duty',
#    'also',
#    'unchanged',
#    '9.92',
#    'cents',
#    '.'],
#   1),
#  (['gao',
#    'likely',
#    'to',
#    'show',
#    'certs',
#    'more',
#    'costly',
#    'than',
#    'cash',
#    'a',
#    'study',
#    'grain',
#    'certificates',
#    'due',
#    'shortly',
#    'government',
#    'accounting',
#    'office',
#    '(',
#    'gao',
#    ')',
#    'could',
#    'show',
#    'certificates',
#    'cost',
#    'government',
#    '10',
#    '15',
#    'pct',
#    'cash',
#    'outlays',
#    ',',
#    'administration',
#    'industry',
#    'sources',
#    'said',
#    '.',
#    'analysis',
#    'gao',
#    'obtained',
#    'agriculture',
#    'department',
#    'office',
#    'management',
#    'budget',
#    'suggests',
#    'certificates',
#    'cost',
#    'cash',
#    'payments',
#    ',',
#    'gao',
#    'official',
#    'told',
#    'reuters',
#    '.',
#    'gao',
#    'preparing',
#    'certificate',
#    'study',
#    'specific',
#    'request',
#    'sen.',
#    'jesse',
#    'helms',
#    '(',
#    'r-n.c.',
#    ')',
#    ',',
#    'former',
#    'chairman',
#    'senate',
#    'agriculture',
#    'committee',
#    '.',
#    'the',
#    'report',
#    ',',
#    'focus',
#    'cost',
#    'certificates',
#    'compared',
#    'cash',
#    ',',
#    'scheduled',
#    'released',
#    'mid',
#    'march',
#    '.',
#    'the',
#    'cost',
#    'certificates',
#    ',',
#    'said',
#    'gao',
#    'source',
#    ',',
#    'depends',
#    'program',
#    "'s",
#    'impact',
#    'usda',
#    'loan',
#    'program',
#    '.',
#    'if',
#    'gao',
#    'determines',
#    'certificates',
#    'encourage',
#    'loan',
#    'entries',
#    'cause',
#    'loan',
#    'forfeitures',
#    ',',
#    'net',
#    'cost',
#    'program',
#    'would',
#    'go',
#    '.',
#    'however',
#    ',',
#    'determined',
#    'certificates',
#    'caused',
#    'government',
#    'grain',
#    'stockpile',
#    'decrease',
#    ',',
#    'cost',
#    'effect',
#    'certificates',
#    'would',
#    'less',
#    '.',
#    'gao',
#    'likely',
#    'suggest',
#    'whether',
#    'certificates',
#    'program',
#    'slowed',
#    'expanded',
#    ',',
#    'gao',
#    'official',
#    'said',
#    '.',
#    'but',
#    'negative',
#    'report',
#    'certificates',
#    '``',
#    'fuel',
#    'fire',
#    'certificates',
#    'weigh',
#    'heavily',
#    'least',
#    'increase',
#    'certificate',
#    'program',
#    ',',
#    "''",
#    'agricultural',
#    'consultant',
#    'said',
#    '.',
#    'the',
#    'omb',
#    'said',
#    'expansion',
#    'program',
#    ',',
#    'usda',
#    'remains',
#    'firmly',
#    'committed',
#    '.'],
#   0),
#  (['eia',
#    'says',
#    'distillate',
#    ',',
#    'gas',
#    'stocks',
#    'off',
#    'in',
#    'week',
#    'distillate',
#    'fuel',
#    'stocks',
#    'held',
#    'primary',
#    'storage',
#    'fell',
#    '3.4',
#    'mln',
#    'barrels',
#    'week',
#    'ended',
#    'feb',
#    '27',
#    '128.4',
#    'mln',
#    'barrels',
#    ',',
#    'energy',
#    'information',
#    'administration',
#    '(',
#    'eia',
#    ')',
#    'said',
#    '.',
#    'in',
#    'weekly',
#    'petroleum',
#    'status',
#    'report',
#    ',',
#    'department',
#    'energy',
#    'agency',
#    'said',
#    'gasoline',
#    'stocks',
#    '100,000',
#    'barrels',
#    'week',
#    '251.5',
#    'mln',
#    'barrels',
#    'refinery',
#    'crude',
#    'oil',
#    'stocks',
#    '3.2',
#    'mln',
#    'barrels',
#    '333.0',
#    'mln',
#    '.',
#    'the',
#    'eia',
#    'said',
#    'residual',
#    'fuel',
#    'stocks',
#    'fell',
#    '2.2',
#    'mln',
#    'barrels',
#    '37.9',
#    'mln',
#    'barrels',
#    'crude',
#    'oil',
#    'stocks',
#    'strategic',
#    'petroleum',
#    'reserve',
#    '(',
#    'spr',
#    ')',
#    '700,000',
#    'barrels',
#    '516.5',
#    'mln',
#    '.',
#    'the',
#    'total',
#    'crude',
#    ',',
#    'refined',
#    'product',
#    'spr',
#    'stocks',
#    'unchanged',
#    '1,575.1',
#    'mln',
#    'barrels',
#    ',',
#    'said',
#    '.'],
#   -1),
#  (['champion',
#    'products',
#    '&',
#    'lt',
#    ';',
#    'ch',
#    '>',
#    'approves',
#    'stock',
#    'split',
#    'champion',
#    'products',
#    'inc',
#    'said',
#    'board',
#    'directors',
#    'approved',
#    'two-for-one',
#    'stock',
#    'split',
#    'common',
#    'shares',
#    'shareholders',
#    'record',
#    'april',
#    '1',
#    ',',
#    '1987',
#    '.',
#    'the',
#    'company',
#    'also',
#    'said',
#    'board',
#    'voted',
#    'recommend',
#    'shareholders',
#    'annual',
#    'meeting',
#    'april',
#    '23',
#    'increase',
#    'authorized',
#    'capital',
#    'stock',
#    'five',
#    'mln',
#    '25',
#    'mln',
#    'shares',
#    '.'],
#   -1),
#  (['brown-forman',
#    'inc',
#    '&',
#    'lt',
#    ';',
#    'bfd',
#    '>',
#    '4th',
#    'qtr',
#    'net',
#    'shr',
#    'one',
#    'dlr',
#    'vs',
#    '73',
#    'cts',
#    'net',
#    '12.6',
#    'mln',
#    'vs',
#    '15.8',
#    'mln',
#    'revs',
#    '337.3',
#    'mln',
#    'vs',
#    '315.2',
#    'mln',
#    'nine',
#    'mths',
#    'shr',
#    '3.07',
#    'dlrs',
#    'vs',
#    '3.08',
#    'dlrs',
#    'net',
#    '66',
#    'mln',
#    'vs',
#    '66.2',
#    'mln',
#    'revs',
#    '1.59',
#    'billion',
#    'vs',
#    '997.1',
#    'mln'],
#   0),
#  (['diamond',
#    'shamrock',
#    '&',
#    'lt',
#    ';',
#    'dia',
#    '>',
#    'raises',
#    'crude',
#    'postings',
#    'diamond',
#    'shamrock',
#    'said',
#    'raised',
#    'contract',
#    'price',
#    'pay',
#    'crude',
#    'oil',
#    '50',
#    'cts',
#    'barrel',
#    ',',
#    'effective',
#    'today',
#    '.',
#    'the',
#    'increase',
#    'brings',
#    'company',
#    "'s",
#    'posted',
#    'price',
#    'benchmark',
#    'grade',
#    ',',
#    'west',
#    'texas',
#    'intermediate',
#    ',',
#    '17.50',
#    'dlrs/bbl',
#    '.',
#    'diamond',
#    'shamrock',
#    'last',
#    'changed',
#    'postings',
#    'march',
#    '4',
#    '.'],
#   -1),
#  (['belgian',
#    'wholesale',
#    'prices',
#    'fall',
#    'in',
#    'january',
#    'belgian',
#    'wholesale',
#    'prices',
#    'fell',
#    '5.9',
#    'pct',
#    'january',
#    'year',
#    'earlier',
#    '5.7',
#    'pct',
#    'year',
#    'year',
#    'fall',
#    'december',
#    ',',
#    'figures',
#    'economics',
#    'ministry',
#    'show',
#    '.',
#    'a',
#    'ministry',
#    'spokesman',
#    'said',
#    'wholesale',
#    'price',
#    'index',
#    ',',
#    'base',
#    '1953',
#    'excluding',
#    'value',
#    'added',
#    'tax',
#    ',',
#    'stood',
#    '250.9',
#    'january',
#    '.',
#    'this',
#    'compared',
#    '251.9',
#    'december',
#    ',',
#    '265.5',
#    'janua~y',
#    ',',
#    '1986',
#    '267.2',
#    'december',
#    ',',
#    '1985',
#    '.',
#    'in',
#    'january',
#    '1986',
#    ',',
#    'wholesale',
#    'prices',
#    '3.9',
#    'pct',
#    'lower',
#    'year',
#    'earlier',
#    '.'],
#   -1),
#  (['northern',
#    'telecom',
#    'proposes',
#    'two-for-one',
#    'stock',
#    'split',
#    'northern',
#    'telecom',
#    'proposes',
#    'two-for-one',
#    'stock',
#    'split'],
#   0),
#  (['computer',
#    'language',
#    'research',
#    'in',
#    '&',
#    'lt',
#    ';',
#    'clri',
#    '>',
#    '4th',
#    'qtr',
#    'shr',
#    'loss',
#    '22',
#    'cts',
#    'vs',
#    'loss',
#    '18',
#    'cts',
#    'net',
#    'loss',
#    '3,035,000',
#    'vs',
#    'loss',
#    '2,516,000',
#    'revs',
#    '20.9',
#    'mln',
#    'vs',
#    '19.6',
#    'mln',
#    'qtly',
#    'div',
#    'three',
#    'cts',
#    'vs',
#    'three',
#    'cts',
#    'prior',
#    'year',
#    'shr',
#    'profit',
#    'two',
#    'cts',
#    'vs',
#    'profit',
#    '34',
#    'cts',
#    'net',
#    'profit',
#    '215,000',
#    'vs',
#    'profit',
#    '4,647,000',
#    'revs',
#    '93.4',
#    'mln',
#    'vs',
#    '98.7',
#    'mln',
#    'note',
#    ':',
#    'dividend',
#    'payable',
#    'april',
#    'one',
#    'shareholders',
#    'record',
#    'march',
#    '17',
#    '.'],
#   0),
#  (['nationwide',
#    'cellular',
#    '&',
#    'lt',
#    ';',
#    'ncel',
#    '>',
#    'completes',
#    'purchase',
#    'nationwide',
#    'cellular',
#    'service',
#    'inc',
#    'said',
#    'completed',
#    'previously-announced',
#    'acquisition',
#    'privately-held',
#    'nova',
#    'cellular',
#    'co',
#    ',',
#    'chicago',
#    'reseller',
#    'mobile',
#    'telephone',
#    'service',
#    '1,800',
#    'subscribers',
#    ',',
#    '65,000',
#    'common',
#    'shares',
#    '.',
#    'nova',
#    'cellular',
#    'accumulated',
#    'deficit',
#    '650,000',
#    'dlrs',
#    'revenues',
#    '2,600,000',
#    'dlrs',
#    '1986',
#    ',',
#    'said',
#    '.'],
#   -1),
#  (['u.s',
#    '.',
#    'wheat',
#    'bonus',
#    'to',
#    'soviet',
#    'called',
#    'dormant',
#    'the',
#    'u.s.',
#    'agriculture',
#    'department',
#    'actively',
#    'considering',
#    'offering',
#    'subsidized',
#    'wheat',
#    'soviet',
#    'union',
#    'export',
#    'enhancement',
#    'program',
#    '(',
#    'eep',
#    ')',
#    ',',
#    'senior',
#    'usda',
#    'officials',
#    'said',
#    '.',
#    'however',
#    ',',
#    'grain',
#    'trade',
#    'analysts',
#    'said',
#    'proposal',
#    'ruled',
#    'offer',
#    'might',
#    'made',
#    ',',
#    'though',
#    'near',
#    'future',
#    '.',
#    '``',
#    'the',
#    'grain',
#    'companies',
#    'trying',
#    'get',
#    'fired',
#    ',',
#    "''",
#    'aide',
#    'agriculture',
#    'secretary',
#    'richard',
#    'lyng',
#    'said',
#    '.',
#    '``',
#    'but',
#    "n't",
#    'much',
#    'talk',
#    ',',
#    'informally',
#    'formally',
#    '.',
#    "''",
#    'most',
#    'analysts',
#    'interviewed',
#    'reuters',
#    'confident',
#    'usda',
#    'officials',
#    'bonus',
#    'wheat',
#    'would',
#    'offered',
#    'soviets',
#    ',',
#    'even',
#    'though',
#    'u.s.',
#    'officials',
#    'make',
#    'offer',
#    'held',
#    'grain',
#    'talks',
#    'soviet',
#    'counterparts',
#    'earlier',
#    'week',
#    '.',
#    'but',
#    'administration',
#    'private',
#    'sources',
#    'agreed',
#    'reagan',
#    'administration',
#    'decide',
#    'offer',
#    'subsidized',
#    'wheat',
#    'moscow',
#    ',',
#    'could',
#    'take',
#    'several',
#    'months',
#    '.',
#    '``',
#    'i',
#    "n't",
#    'see',
#    'proposal',
#    'like',
#    'sailing',
#    'interagency',
#    'process',
#    ',',
#    "''",
#    'aide',
#    'lyng',
#    'said',
#    '.',
#    '``',
#    'an',
#    'export',
#    'enhancement',
#    'offer',
#    'consummated',
#    'overnight',
#    ',',
#    "''",
#    'said',
#    'one',
#    'former',
#    'usda',
#    'official',
#    ',',
#    'noted',
#    'administration',
#    'took',
#    'three',
#    'months',
#    'decide',
#    'favor',
#    'selling',
#    'china',
#    'wheat',
#    'subsidy',
#    'program',
#    '.',
#    'an',
#    'official',
#    'representing',
#    'large',
#    'grain',
#    'trade',
#    'company',
#    'said',
#    'deliberations',
#    'within',
#    'usda',
#    'might',
#    'nudged',
#    'along',
#    'members',
#    'congress',
#    ',',
#    'number',
#    'urged',
#    'usda',
#    'week',
#    'make',
#    'wheat',
#    'subsidy',
#    'offer',
#    'soviets',
#    '.',
#    'but',
#    'lyng',
#    "'s",
#    'aide',
#    'said',
#    'day-long',
#    'visit',
#    'capitol',
#    'hill',
#    'yesterday',
#    ',',
#    'house',
#    'members',
#    'press',
#    'secretary',
#    'subsidy',
#    'question',
#    'single',
#    'time',
#    '.',
#    'the',
#    'administration',
#    "'s",
#    'interagency',
#    'trade',
#    'policy',
#    'review',
#    'group',
#    ',',
#    'comprised',
#    'subcabinet-level',
#    'officials',
#    ',',
#    'asked',
#    'clear',
#    'request',
#    'offer',
#    'moscow',
#    'wheat',
#    'eep',
#    ',',
#    'officials',
#    'u.s.',
#    'trade',
#    'representative',
#    "'s",
#    'office',
#    'said',
#    '.',
#    'in',
#    'talks',
#    'week',
#    ',',
#    'two',
#    'sides',
#    'discussed',
#    'administration',
#    "'s",
#    'previous',
#    'eep',
#    'offer',
#    'talk',
#    'new',
#    'initiative',
#    '.',
#    'one',
#    'usda',
#    'official',
#    'took',
#    'part',
#    'consultations',
#    'week',
#    'described',
#    'exchange',
#    '``',
#    'calm',
#    ',',
#    'basic',
#    ',',
#    'factual',
#    'economics',
#    '.',
#    "''",
#    'another',
#    'usda',
#    'official',
#    'said',
#    '``',
#    'even',
#    'informal',
#    'suggestion',
#    'hint',
#    "''",
#    'soviets',
#    'would',
#    'live',
#    'pledge',
#    'buy',
#    'four',
#    'mln',
#    'tonnes',
#    'wheat',
#    'year',
#    'granted',
#    'favorable',
#    'terms',
#    '.',
#    'usda',
#    'private',
#    'sources',
#    'agreed',
#    'consideration',
#    'eep',
#    'initiative',
#    'interagency',
#    'review',
#    'groups',
#    'likely',
#    'would',
#    'delayed',
#    'disarray',
#    'within',
#    'white',
#    'house',
#    'stemming',
#    'iran',
#    'arms',
#    'affair',
#    '.'],
#   0),
#  (['techamerica',
#    'group',
#    'inc',
#    '&',
#    'lt',
#    ';',
#    'tch',
#    '>',
#    '4th',
#    'qtr',
#    'loss',
#    'shr',
#    'loss',
#    'six',
#    'cts',
#    'vs',
#    'available',
#    'net',
#    'loss',
#    '562,231',
#    'vs',
#    'profit',
#    '10,253',
#    'revs',
#    '8,871,874',
#    'vs',
#    '9,549,308',
#    'year',
#    'shr',
#    'loss',
#    '60',
#    'cts',
#    'vs',
#    'loss',
#    'nine',
#    'cts',
#    'net',
#    'loss',
#    '5,058,145',
#    'vs',
#    'loss',
#    '766,185',
#    'revs',
#    '34.3',
#    'mln',
#    'vs',
#    '35.5',
#    'mln'],
#   0),
#  (['cronus',
#    'industries',
#    'inc',
#    '&',
#    'lt',
#    ';',
#    'crns',
#    '>',
#    'sells',
#    'unit',
#    'cronus',
#    'industries',
#    'inc',
#    'said',
#    'agreed',
#    'sell',
#    'heat',
#    'transfer',
#    'equipment',
#    'business',
#    ',',
#    'southwestern',
#    'engineering',
#    'co',
#    ',',
#    'slight',
#    'premium',
#    'book',
#    'value',
#    ',',
#    'plus',
#    'release',
#    'cronus',
#    'liability',
#    'approximately',
#    'three',
#    'mln',
#    'dlrs',
#    'subsidiary',
#    'indebtedness',
#    '.',
#    'the',
#    'company',
#    'said',
#    'sale',
#    'subsidiary',
#    'senior',
#    'engineering',
#    'group',
#    'plc',
#    ',',
#    'british',
#    'company',
#    ',',
#    'take',
#    'place',
#    'month',
#    '.'],
#   -1),
#  (['canon',
#    'inc',
#    '(',
#    'cann.t',
#    ')',
#    'year',
#    'ended',
#    'decmeber',
#    '31',
#    'group',
#    'shr',
#    '18.34',
#    'yen',
#    'vs',
#    '58.72',
#    'net',
#    '10.73',
#    'billion',
#    'yen',
#    'vs',
#    '37.06',
#    'billion',
#    'pretax',
#    '27.76',
#    'billion',
#    'yen',
#    'vs',
#    '84.78',
#    'billion',
#    'operating',
#    '30.06',
#    'billion',
#    'yen',
#    'vs',
#    '88.81',
#    'billion',
#    'sales',
#    '889.22',
#    'billion',
#    'vs',
#    '955.78',
#    'billion',
#    'note',
#    '-',
#    'the',
#    'company',
#    'attributed',
#    'profit',
#    'fall',
#    'largely',
#    'yen',
#    "'s",
#    'appreciation',
#    'period',
#    '.',
#    'domestic',
#    'sales',
#    'rose',
#    '0.4',
#    'pct',
#    '274.17',
#    'billion',
#    'yen',
#    'year',
#    'earlier',
#    'exports',
#    'declined',
#    '9.9',
#    'pct',
#    '615.04',
#    'billion',
#    '.'],
#   1),
#  (['gulf',
#    'applied',
#    'technologies',
#    '&',
#    'lt',
#    ';',
#    'gats',
#    '>',
#    'sells',
#    'units',
#    'gulf',
#    'applied',
#    'technologies',
#    'inc',
#    'said',
#    'sold',
#    'subsidiaries',
#    'engaged',
#    'pipeline',
#    'terminal',
#    'operations',
#    '12.2',
#    'mln',
#    'dlrs',
#    '.',
#    'the',
#    'company',
#    'said',
#    'sale',
#    'subject',
#    'certain',
#    'post',
#    'closing',
#    'adjustments',
#    ',',
#    'explain',
#    '.'],
#   0),
#  (['swiss',
#    'capital',
#    'exports',
#    'rise',
#    'in',
#    'january',
#    'swiss',
#    'capital',
#    'exports',
#    'rose',
#    '4.64',
#    'billion',
#    'francs',
#    'january',
#    '2.54',
#    'billion',
#    'december',
#    'year',
#    'earlier',
#    '3.64',
#    'billion',
#    ',',
#    'swiss',
#    'national',
#    'bank',
#    'said',
#    '.',
#    'new',
#    'bond',
#    'issues',
#    'accounted',
#    '4.12',
#    'billion',
#    'total',
#    'december',
#    "'s",
#    '2.15',
#    'billion',
#    ',',
#    'credits',
#    '525.1',
#    'mln',
#    '389.9',
#    'mln',
#    '.',
#    'in',
#    'january',
#    '1985',
#    ',',
#    'national',
#    'bank',
#    'ended',
#    'distinction',
#    'notes',
#    'bonds',
#    ',',
#    'bond',
#    'issues',
#    'totalled',
#    '1.66',
#    'billion',
#    'francs',
#    ',',
#    'notes',
#    '1.39',
#    'billion',
#    'credits',
#    '597.5',
#    'mln',
#    '.'],
#   1),
#  (['swiss',
#    'economy',
#    'in',
#    'excellent',
#    'condition',
#    ',',
#    'oecd',
#    'says',
#    'switzerland',
#    "'s",
#    'economy',
#    ',',
#    'combining',
#    'low',
#    'unemployment',
#    ',',
#    'financial',
#    'stability',
#    'large',
#    'external',
#    'payments',
#    'surplus',
#    ',',
#    'excellent',
#    'condition',
#    'faces',
#    'satisfactory',
#    'future',
#    ',',
#    'organisation',
#    'economic',
#    'cooperation',
#    'development',
#    ',',
#    'oecd',
#    ',',
#    'said',
#    '.',
#    'this',
#    'reflected',
#    'success',
#    'stable',
#    'relatively',
#    'tight',
#    'fiscal',
#    'monetary',
#    'policies',
#    'followed',
#    'government',
#    ',',
#    'said',
#    '.',
#    'the',
#    'oecd',
#    ',',
#    'annual',
#    'report',
#    'switzerland',
#    ',',
#    'picked',
#    'signs',
#    'slowdown',
#    'activity',
#    'slight',
#    'pick-up',
#    'inflation',
#    'year',
#    ',',
#    'said',
#    'gave',
#    'cause',
#    'concern',
#    '.',
#    'the',
#    'study',
#    'forecast',
#    'decline',
#    'gross',
#    'domestic',
#    'product',
#    'growth',
#    '1.75',
#    'pct',
#    'year',
#    'estimated',
#    'two',
#    'pct',
#    '1986',
#    'small',
#    'rise',
#    'consumer',
#    'price',
#    'inflation',
#    '1.25',
#    'pct',
#    'last',
#    'year',
#    "'s",
#    'sharp',
#    'fall',
#    '0.75',
#    'pct',
#    '3.6',
#    'pct',
#    '1985',
#    '.',
#    'but',
#    'said',
#    'job',
#    'creation',
#    'continue',
#    'absorb',
#    'modest',
#    'increase',
#    'workforce',
#    ',',
#    'leaving',
#    'unemployment',
#    'rate',
#    'unchanged',
#    'around',
#    'one',
#    'pct',
#    ',',
#    'lowest',
#    '24-industrial',
#    'nation',
#    'oecd',
#    'area',
#    '.',
#    'assuming',
#    'average',
#    'exchange',
#    'rate',
#    '1.71',
#    'swiss',
#    'francs',
#    'dollar',
#    'year',
#    ',',
#    '1.69',
#    'second',
#    'half',
#    '1986',
#    ',',
#    'report',
#    'forecast',
#    '2.75',
#    'pct',
#    'rise',
#    'exports',
#    '3.5',
#    'pct',
#    'rise',
#    'imports',
#    'year',
#    'rises',
#    '3.25',
#    'pct',
#    '6.5',
#    'pct',
#    'respectively',
#    '1986',
#    '.',
#    'the',
#    'faster',
#    'growth',
#    'imports',
#    'compared',
#    'exports',
#    'year',
#    'last',
#    ',',
#    'reflecting',
#    'buoyant',
#    'private',
#    'consumption',
#    ',',
#    'meant',
#    'contribution',
#    'foreign',
#    'payments',
#    'balance',
#    'gdp',
#    'would',
#    'shrink',
#    'years',
#    '.',
#    'but',
#    '``',
#    'given',
#    'switzerland',
#    "'s",
#    'large',
#    'external',
#    'surplus',
#    ',',
#    'concern',
#    'domestic',
#    'demand',
#    'grows',
#    'faster',
#    'gdp',
#    '...',
#    'which',
#    ',',
#    'small',
#    'way',
#    ',',
#    'would',
#    'contribute',
#    'improving',
#    'international',
#    'balances',
#    ',',
#    "''",
#    'oecd',
#    'said',
#    '.',
#    'real',
#    'private',
#    'consumption',
#    'appeared',
#    'unusually',
#    'buoyant',
#    'last',
#    'year',
#    ',',
#    '3.25',
#    'pct',
#    'growth',
#    'rate',
#    ',',
#    'several',
#    'years',
#    'relative',
#    'weakness',
#    ',',
#    'noted',
#    '.',
#    'in',
#    '1987',
#    'private',
#    'consumption',
#    'expected',
#    'slow',
#    'somewhat',
#    '2.25',
#    'pct',
#    'growth',
#    'rate',
#    ',',
#    'still',
#    'outstrip',
#    'overall',
#    'gdp',
#    ',',
#    'added',
#    '.',
#    'the',
#    'outlook',
#    'investment',
#    'plant',
#    'machinery',
#    'remained',
#    'bright',
#    '1987',
#    ',',
#    'capacity',
#    'use',
#    'near',
#    'record',
#    'levels',
#    'last',
#    'year',
#    'scope',
#    'rationalisation',
#    'modernisation',
#    'industry',
#    'service',
#    'sectors',
#    ',',
#    'said',
#    '.',
#    'as',
#    'consequence',
#    ',',
#    'growth',
#    'machinery',
#    'equipment',
#    'investment',
#    'likely',
#    'decelerate',
#    'slightly',
#    'year',
#    'vigorous',
#    'growth',
#    '1986',
#    '.',
#    'but',
#    'report',
#    'raised',
#    'questionmark',
#    'prospects',
#    'tourism',
#    'banking',
#    'industry',
#    ',',
#    'two',
#    'major',
#    'service',
#    'sector',
#    'earners',
#    'foreign',
#    'exchange',
#    '.',
#    'the',
#    'long-term',
#    'appreciation',
#    'swiss',
#    'franc',
#    ',',
#    'accelerating',
#    'deregulation',
#    'foreign',
#    'banking',
#    'markets',
#    ',',
#    'could',
#    'lead',
#    'loss',
#    'international',
#    'market',
#    'share',
#    ',',
#    'said',
#    '.',
#    'particularly',
#    'banks',
#    ',',
#    '``',
#    'recent',
#    'developments',
#    'international',
#    'financial',
#    'markets',
#    'give',
#    'rise',
#    'question',
#    'whether',
#    'swiss',
#    'financial',
#    'system',
#    ',',
#    'shown',
#    'substantial',
#    'flexibility',
#    'past',
#    ',',
#    'adapting',
#    'speed',
#    'required',
#    '...',
#    'to',
#    'preserve',
#    'competitive',
#    'position',
#    ',',
#    "''",
#    'said',
#    '.'],
#   0),
#  (['coradian',
#    'corp',
#    '&',
#    'lt',
#    ';',
#    'cdin',
#    '>',
#    '4th',
#    'qtr',
#    'net',
#    'shr',
#    'profit',
#    'three',
#    'cts',
#    'vs',
#    'loss',
#    'three',
#    'cts',
#    'net',
#    'profit',
#    '363,000',
#    'vs',
#    'loss',
#    '197,000',
#    'revs',
#    '3,761,000',
#    'vs',
#    '2,666,000',
#    'year',
#    'shr',
#    'profit',
#    'one',
#    'cent',
#    'vs',
#    'loss',
#    '37',
#    'cts',
#    'net',
#    'profit',
#    '129,000',
#    'vs',
#    'loss',
#    '1,715,000',
#    'revs',
#    '11.4',
#    'mln',
#    'vs',
#    '10.9',
#    'mln',
#    'avg',
#    'shrs',
#    '10,694,081',
#    'vs',
#    '4,673,253'],
#   0),
#  (['brown-forman',
#    '&',
#    'lt',
#    ';',
#    'bfdb',
#    '>',
#    'sets',
#    'stock',
#    'split',
#    ',',
#    'ups',
#    'payout',
#    'brown-forman',
#    'inc',
#    'said',
#    'board',
#    'approved',
#    'three-for-two',
#    'stock',
#    'split',
#    '35',
#    'pct',
#    'increase',
#    'company',
#    'cash',
#    'dividend',
#    '.',
#    'the',
#    'company',
#    'cited',
#    'improved',
#    'earnings',
#    'outlook',
#    'continued',
#    'strong',
#    'cash',
#    'flow',
#    'reasons',
#    'raising',
#    'dividend',
#    '.',
#    'brown-forman',
#    'said',
#    'split',
#    'class',
#    'a',
#    'class',
#    'b',
#    'common',
#    'shares',
#    'would',
#    'effective',
#    'march',
#    '13',
#    '.',
#    'the',
#    'company',
#    'said',
#    'directors',
#    'declared',
#    'quarterly',
#    'cash',
#    'dividend',
#    'new',
#    'share',
#    'classes',
#    '28',
#    'cts',
#    ',',
#    'payable',
#    'april',
#    'one',
#    'holders',
#    'record',
#    'march',
#    '20',
#    '.',
#    'prior',
#    'split',
#    ',',
#    'company',
#    'paid',
#    '31',
#    'cts',
#    'quarterly',
#    '.',
#    'brown-forman',
#    'today',
#    'reported',
#    '37',
#    'pct',
#    'increase',
#    'third',
#    'quarter',
#    'profits',
#    '21.6',
#    'mln',
#    'dlrs',
#    ',',
#    '1.00',
#    'dlr',
#    'share',
#    ',',
#    'seven',
#    'pct',
#    'increase',
#    'sales',
#    'record',
#    '337',
#    'mln',
#    'dlrs',
#    '.',
#    'brown-forman',
#    'said',
#    'nine',
#    'month',
#    'profits',
#    'declined',
#    'bit',
#    '66.0',
#    'mln',
#    'dlrs',
#    ',',
#    '3.07',
#    'dlrs',
#    'share',
#    ',',
#    '66.2',
#    'mln',
#    'dlrs',
#    ',',
#    '3.08',
#    'dlrs',
#    'share',
#    ',',
#    'year',
#    'earlier',
#    'due',
#    'second',
#    'quarter',
#    'charge',
#    '37',
#    'cts',
#    'share',
#    'restructuring',
#    'beverage',
#    'operations',
#    '.',
#    'the',
#    'company',
#    'said',
#    'lower',
#    'corporate',
#    'tax',
#    'rates',
#    'restructuring',
#    '``',
#    'expected',
#    'substantially',
#    'improve',
#    'brown-forman',
#    "'s",
#    'earnings',
#    'cash',
#    'flow',
#    'fiscal',
#    '1988',
#    '.',
#    "''"],
#   0),
#  (['cri',
#    'insured',
#    '&',
#    'lt',
#    ';',
#    'cii',
#    '>',
#    'to',
#    'set',
#    'special',
#    'distribution',
#    'cri',
#    'insured',
#    'mortgage',
#    'investments',
#    'inc',
#    'said',
#    'advisor',
#    'recommend',
#    'special',
#    'distribution',
#    '50',
#    'cts',
#    'per',
#    'share',
#    'due',
#    'sale',
#    'federally',
#    'insured',
#    'first',
#    'mortgage',
#    'park',
#    'meadows',
#    'i',
#    'madison',
#    ',',
#    'wis.',
#    ',',
#    '4,267,871',
#    'dlrs',
#    '.',
#    'it',
#    'said',
#    'received',
#    '3,695,465',
#    'dlr',
#    'return',
#    'capital',
#    '572,406',
#    'dlrs',
#    'income',
#    'sale',
#    ',',
#    '50',
#    'ct',
#    'distribution',
#    'would',
#    'represent',
#    '43.294',
#    'ct',
#    'return',
#    'principal',
#    '6.706',
#    'ct',
#    'capital',
#    'gain',
#    'would',
#    'payable',
#    'june',
#    '30',
#    'holders',
#    'record',
#    'may',
#    '31',
#    '.'],
#   1),
#  (['u.s.',
#    'wine',
#    'exports',
#    'rose',
#    '15',
#    'per',
#    'cent',
#    'last',
#    'year',
#    'exports',
#    'american',
#    'wine',
#    'rose',
#    '14.9',
#    'per',
#    'cent',
#    'last',
#    'year',
#    'total',
#    '7.2',
#    'million',
#    'gallons',
#    ',',
#    'wine',
#    'institute',
#    'said',
#    '.',
#    'the',
#    'san',
#    'francisco-based',
#    'promotional',
#    'group',
#    'said',
#    '95',
#    'per',
#    'cent',
#    'exported',
#    'wine',
#    'california',
#    'top',
#    'three',
#    'markets',
#    'canada',
#    ',',
#    'japan',
#    'britain',
#    '.',
#    'japan',
#    ',',
#    'edged',
#    'britain',
#    'leading',
#    'importer',
#    'american',
#    'wines',
#    '1985',
#    ',',
#    'continued',
#    'second',
#    'place',
#    '.',
#    'canadian',
#    'imports',
#    'rose',
#    '3.2',
#    'per',
#    'cent',
#    '2.6',
#    'million',
#    'gallons',
#    ';',
#    'japan',
#    ',',
#    '9.9',
#    'per',
#    'cent',
#    '1.2',
#    'million',
#    'gallons',
#    ',',
#    'britain',
#    ',',
#    '20.2',
#    'per',
#    'cent',
#    '962,360',
#    'gallons',
#    '.',
#    'a',
#    'spokesman',
#    'institute',
#    'said',
#    'declining',
#    'value',
#    'dollar',
#    'strong',
#    'promotional',
#    'efforts',
#    'part',
#    'california',
#    'wine',
#    'industry',
#    'contributed',
#    'significantly',
#    'increased',
#    'shipments',
#    '.',
#    'the',
#    '1986',
#    'wine',
#    'exports',
#    'valued',
#    '34.7',
#    'mln',
#    'dlrs',
#    ',',
#    '27.6',
#    'mln',
#    'dlrs',
#    'previous',
#    'year',
#    '.'],
#   1),
#  (['venezuela',
#    'moves',
#    'closer',
#    'to',
#    'champlin',
#    'purchase',
#    'council',
#    'ministers',
#    'approved',
#    'petroleos',
#    'de',
#    'venezuela',
#    "'s",
#    'planned',
#    'purchase',
#    'half',
#    'interest',
#    'champlin',
#    'petroleum',
#    'refinery',
#    'corpus',
#    'christi',
#    ',',
#    'texas',
#    ',',
#    'government',
#    'sources',
#    'said',
#    '.',
#    'the',
#    'cabinet',
#    'authorized',
#    'energy',
#    'mines',
#    'minister',
#    'arturo',
#    'hernandez',
#    'grisanti',
#    'approve',
#    'purchase',
#    'shareholders',
#    'assembly',
#    'state',
#    'oil',
#    'company',
#    'petroleos',
#    'de',
#    'venezuela',
#    '(',
#    'pdvsa',
#    ')',
#    '.',
#    'pdvsa',
#    'last',
#    'april',
#    '14',
#    'signed',
#    'letter',
#    'intent',
#    'buy',
#    'half',
#    'interest',
#    'champlin',
#    "'s",
#    'corpus',
#    'christi',
#    'refinery',
#    'undisclosed',
#    'sum',
#    '.',
#    'under',
#    'terms',
#    'provisional',
#    'agreement',
#    ',',
#    'venezuela',
#    'would',
#    'supply',
#    '160,000',
#    'barrels',
#    'day',
#    'plant',
#    'new',
#    'company',
#    'would',
#    'jointly',
#    'owned',
#    'pdvsa',
#    'champlin',
#    ',',
#    'subsidiary',
#    'union',
#    'pacific',
#    'corp',
#    '&',
#    'lt',
#    ';',
#    'unp',
#    '>',
#    '.',
#    'the',
#    'deal',
#    'would',
#    'also',
#    'allow',
#    'pdvsa',
#    'joint',
#    'share',
#    "champlin's",
#    'refinery',
#    'distribution',
#    'network',
#    '.',
#    'the',
#    'purhcase',
#    'one',
#    'series',
#    'overseas',
#    'joint',
#    'ventures',
#    'venezuela',
#    'managed',
#    'assure',
#    'markets',
#    '400,000',
#    'barrels',
#    'approximately',
#    '1.5',
#    'mln',
#    'bpd',
#    'exports',
#    '.',
#    'hernandez',
#    'grisanti',
#    'told',
#    'reporters',
#    'cabinet',
#    'meeting',
#    'pdvsa',
#    'pay',
#    '93',
#    'mln',
#    'dlrs',
#    'half',
#    'ownership',
#    'champlin',
#    'refinery',
#    '-',
#    '33',
#    'mln',
#    'dlrs',
#    'cash',
#    '60',
#    'mln',
#    'dlrs',
#    'crude',
#    'oil',
#    'products',
#    '.',
#    'through',
#    'deal',
#    ',',
#    'said',
#    ',',
#    'venezuela',
#    'assured',
#    'sale',
#    'least',
#    '140,000',
#    'bpd',
#    'crude',
#    'products',
#    '.',
#    'hernandez',
#    'said',
#    'pdsva',
#    'entered',
#    'similar',
#    'joint',
#    'ventures',
#    'veba',
#    'oel',
#    'west',
#    'germany',
#    ',',
#    'nynas',
#    'petroelum',
#    'sweden',
#    ',',
#    'citgo',
#    'united',
#    'states',
#    '.'],
#   -1),
#  (['usda',
#    'orange',
#    'juice',
#    'yield',
#    'estimate',
#    'the',
#    'u.s.',
#    'agriculture',
#    'department',
#    'projected',
#    'average',
#    'yield',
#    '1.47',
#    'gallons',
#    'frozen',
#    'concentrated',
#    'orange',
#    'juice',
#    'per',
#    'box',
#    '(',
#    '42.0',
#    'degree',
#    'brix',
#    'equivalent',
#    ')',
#    'florida',
#    "'s",
#    '1986/87',
#    'crop',
#    '.',
#    'that',
#    'compares',
#    '1.46',
#    'gallons',
#    'per',
#    'box',
#    'previously',
#    '1.38',
#    'gallons',
#    'per',
#    'box',
#    '1985/86',
#    'crop',
#    '.',
#    'the',
#    'crop',
#    'reporting',
#    'board',
#    'said',
#    'estimates',
#    '1986/87',
#    'season',
#    'based',
#    'maturity',
#    'yields',
#    'tests',
#    'march',
#    '1',
#    '.'],
#   -1),
#  (['potomac',
#    'electric',
#    'power',
#    'co',
#    '&',
#    'lt',
#    ';',
#    'pom',
#    '>',
#    'jan',
#    'net',
#    'shr',
#    '27',
#    'cts',
#    'vs',
#    '29',
#    'cts',
#    'net',
#    '13,555,000',
#    'vs',
#    '14,635,000',
#    'revs',
#    '104,606,000',
#    'vs',
#    '110,311,000',
#    'avg',
#    'shrs',
#    '47.2',
#    'mln',
#    'vs',
#    '47.1',
#    'mln',
#    '12',
#    'mths',
#    'shr',
#    '4.10',
#    'dlrs',
#    'vs',
#    '3.66',
#    'dlrs',
#    'net',
#    '226,653,000',
#    'vs',
#    '186,790,000',
#    'revs',
#    '1.4',
#    'billion',
#    'vs',
#    '1.3',
#    'billion',
#    'avg',
#    'shr',
#    '47.1',
#    'mln',
#    'vs',
#    '47.1',
#    'mln',
#    'note',
#    ':',
#    'latest',
#    '12',
#    'mths',
#    'net',
#    'includes',
#    'gain',
#    '46',
#    'cts',
#    'per',
#    'share',
#    'sale',
#    'virginia',
#    'service',
#    'territory',
#    'dominion',
#    'resources',
#    'inc',
#    '&',
#    'lt',
#    ';',
#    'd',
#    '>',
#    '.'],
#   0),
#  (['emhart',
#    'corp',
#    '&',
#    'lt',
#    ';',
#    'emh',
#    '>',
#    'qtly',
#    'dividend',
#    'qtly',
#    'div',
#    '35',
#    'cts',
#    'vs',
#    '35',
#    'cts',
#    'prior',
#    'payable',
#    'march',
#    '31',
#    'record',
#    'march',
#    'nine'],
#   0),
#  (['powerine',
#    'refinery',
#    'to',
#    'resume',
#    'operations',
#    '&',
#    'lt',
#    ';',
#    'powerine',
#    'oil',
#    'co',
#    '>',
#    'said',
#    'refinery',
#    'resume',
#    'operation',
#    'today',
#    ',',
#    'initial',
#    'crude',
#    'oil',
#    'runs',
#    '20,000',
#    'barrels',
#    'per',
#    'day',
#    '.',
#    'powerine',
#    ',',
#    'privately-held',
#    'company',
#    ',',
#    'said',
#    'expects',
#    'refinery',
#    'become',
#    'fully',
#    'operational',
#    'may',
#    ',',
#    'crude',
#    'oil',
#    'throughput',
#    '35,000',
#    'bpd',
#    '.',
#    'initial',
#    'oil',
#    'products',
#    'deliveries',
#    'scheduled',
#    'monday',
#    ',',
#    'powerine',
#    'said',
#    '.',
#    'the',
#    'refinery',
#    'closed',
#    'due',
#    'change',
#    'ownership',
#    ',',
#    'company',
#    'said',
#    '.'],
#   -1),
#  (['nippon',
#    'steel',
#    'invests',
#    '8',
#    'mln',
#    'dlrs',
#    'in',
#    'gtx',
#    'corp',
#    'gtx',
#    'corp',
#    'said',
#    'nippon',
#    'steel',
#    'co',
#    'japan',
#    ',',
#    'move',
#    'diversify',
#    'high',
#    'technology',
#    ',',
#    'invested',
#    'eight',
#    'mln',
#    'dlrs',
#    'gtx',
#    '.',
#    'nippon',
#    "'s",
#    'move',
#    'result',
#    'current',
#    'exchange',
#    'rates',
#    'revaluation',
#    'yen',
#    ',',
#    '``',
#    'made',
#    'u.s.',
#    'electronics',
#    'industry',
#    'attractive',
#    'investment',
#    'opportunity',
#    'japanese',
#    'corporations',
#    ',',
#    "''",
#    'according',
#    'gtx',
#    'statement',
#    '.',
#    'gtx',
#    'noted',
#    'nippon',
#    'expecting',
#    'sales',
#    '27',
#    'billion',
#    'dlrs',
#    '1995',
#    '.',
#    'of',
#    'amount',
#    ',',
#    'six',
#    'billion',
#    'dlrs',
#    'targeted',
#    'electronics',
#    '.',
#    'gtx',
#    ',',
#    'located',
#    'phoenix',
#    ',',
#    'makes',
#    'computerized',
#    'systems',
#    'read',
#    'drawings',
#    'transfer',
#    'data',
#    'bases',
#    '.'],
#   1),
#  (['systematics',
#    'inc',
#    '&',
#    'lt',
#    ';',
#    'syst',
#    '>',
#    'regular',
#    'payout',
#    'qtly',
#    'div',
#    'three',
#    'cts',
#    'vs',
#    'three',
#    'cts',
#    'prior',
#    'pay',
#    'march',
#    '13',
#    'record',
#    'february',
#    '27'],
#   0),
#  (['u.k.',
#    'money',
#    'market',
#    'shortage',
#    'forecast',
#    'revised',
#    'down',
#    'the',
#    'bank',
#    'england',
#    'said',
#    'revised',
#    'forecast',
#    'shortage',
#    'money',
#    'market',
#    '450',
#    'mln',
#    'stg',
#    'taking',
#    'account',
#    'morning',
#    'operations',
#    '.',
#    'at',
#    'noon',
#    'bank',
#    'estimated',
#    'shortfall',
#    '500',
#    'mln',
#    'stg',
#    '.'],
#   -1),
#  (['taiwan',
#    'issues',
#    'more',
#    'cds',
#    'to',
#    'curb',
#    'money',
#    'supply',
#    'growth',
#    'the',
#    'central',
#    'bank',
#    'issued',
#    '7.08',
#    'billion',
#    'dlrs',
#    'worth',
#    'certificates',
#    'deposit',
#    '(',
#    'cds',
#    ')',
#    ',',
#    'bringing',
#    'value',
#    'cd',
#    'issues',
#    'far',
#    'year',
#    '93.29',
#    'billion',
#    ',',
#    'bank',
#    'spokesman',
#    'told',
#    'reuters',
#    '.',
#    'the',
#    'new',
#    'cds',
#    ',',
#    'maturities',
#    'six',
#    'months',
#    ',',
#    'one',
#    'year',
#    'two',
#    'years',
#    ',',
#    'carry',
#    'interest',
#    'rates',
#    'ranging',
#    '3.9',
#    '5.15',
#    'pct',
#    '.',
#    'the',
#    'issues',
#    'designed',
#    'help',
#    'curb',
#    'growth',
#    'm-1b',
#    'money',
#    'supply',
#    'expanded',
#    'along',
#    'taiwan',
#    "'s",
#    'foreign',
#    'exchange',
#    'reserves',
#    ',',
#    'spokesman',
#    'said',
#    '.',
#    'the',
#    'reserves',
#    'reached',
#    'record',
#    'high',
#    '51',
#    'billion',
#    'u.s.',
#    'dlrs',
#    'wednesday',
#    '.'],
#   1),
#  (['firstcorp',
#    '&',
#    'lt',
#    ';',
#    'fcr',
#    '>',
#    'sees',
#    'gain',
#    'on',
#    'condemnation',
#    'firstcorp',
#    'inc',
#    'said',
#    'weill',
#    'report',
#    'after-tax',
#    'gain',
#    '1,827,000',
#    'dlrs',
#    '56',
#    'cts',
#    'per',
#    'share',
#    'primary',
#    '42',
#    'cts',
#    'fully',
#    'diluted',
#    'proposed',
#    'condemnation',
#    'acquisition',
#    'parking',
#    'deck',
#    'operates',
#    'wake',
#    'county',
#    '.',
#    'the',
#    'company',
#    'said',
#    'reinvested',
#    'proceeds',
#    'similar',
#    'property',
#    'within',
#    '24',
#    'months',
#    ',',
#    'gain',
#    'sale',
#    'would',
#    'deferred',
#    'tax',
#    'purposes',
#    '.'],
#   1),
#  (['liebert',
#    'corp',
#    '&',
#    'lt',
#    ';',
#    'lieb',
#    '>',
#    'approves',
#    'merger',
#    'liebert',
#    'corp',
#    'said',
#    'shareholders',
#    'approved',
#    'merger',
#    'wholly-owned',
#    'subsidiary',
#    'emerson',
#    'electric',
#    'co',
#    '&',
#    'lt',
#    ';',
#    'emr',
#    '>',
#    '.',
#    'under',
#    'terms',
#    'merger',
#    ',',
#    'liebert',
#    'shareholder',
#    'receive',
#    '.3322',
#    'shares',
#    'emerson',
#    'stock',
#    'liebert',
#    'share',
#    '.'],
#   0),
#  (['cobanco',
#    'inc',
#    '&',
#    'lt',
#    ';',
#    'cbco',
#    '>',
#    'year',
#    'net',
#    'shr',
#    '34',
#    'cts',
#    'vs',
#    '1.19',
#    'dlrs',
#    'net',
#    '807,000',
#    'vs',
#    '2,858,000',
#    'assets',
#    '510.2',
#    'mln',
#    'vs',
#    '479.7',
#    'mln',
#    'deposits',
#    '472.3',
#    'mln',
#    'vs',
#    '440.3',
#    'mln',
#    'loans',
#    '299.2',
#    'mln',
#    'vs',
#    '327.2',
#    'mln',
#    'note',
#    ':',
#    '4th',
#    'qtr',
#    'available',
#    '.',
#    'year',
#    'includes',
#    '1985',
#    'extraordinary',
#    'gain',
#    'tax',
#    'carry',
#    'forward',
#    '132,000',
#    'dlrs',
#    ',',
#    'five',
#    'cts',
#    'per',
#    'shr',
#    '.'],
#   0),
#  (['novell',
#    '&',
#    'lt',
#    ';',
#    'novl',
#    '>',
#    'sets',
#    'two',
#    'for',
#    'one',
#    'stock',
#    'split',
#    'novell',
#    'inc',
#    'said',
#    'board',
#    'declared',
#    'two-for-one',
#    'stock',
#    'split',
#    ',',
#    'payable',
#    'holders',
#    'record',
#    'close',
#    'business',
#    'march',
#    '31',
#    '.',
#    'it',
#    'said',
#    'shareholders',
#    'annual',
#    'meeting',
#    'approved',
#    'doubling',
#    'authorized',
#    'common',
#    'shares',
#    '30',
#    'mln',
#    '15',
#    'mln',
#    'limitation',
#    'directors',
#    "'",
#    'liability',
#    '.'],
#   -1),
#  (['up-right',
#    'inc',
#    '&',
#    'lt',
#    ';',
#    'upri',
#    '>',
#    '4th',
#    'qtr',
#    'oper',
#    'net',
#    'oper',
#    'shr',
#    'five',
#    'cts',
#    'vs',
#    '29',
#    'cts',
#    'oper',
#    'net',
#    '151,000',
#    'vs',
#    '867,000',
#    'revs',
#    '12.7',
#    'mln',
#    'vs',
#    '14.1',
#    'mln',
#    'year',
#    'oper',
#    'shr',
#    '87',
#    'cts',
#    'vs',
#    '52',
#    'cts',
#    'oper',
#    'net',
#    '2,650,000',
#    'vs',
#    '1,565,000',
#    'revs',
#    '54.7',
#    'mln',
#    'vs',
#    '49.1',
#    'mln',
#    'note',
#    ':',
#    'oper',
#    'data',
#    'include',
#    '4th',
#    'qtr',
#    '1986',
#    'extraordinary',
#    'credit',
#    '14,000',
#    'dlrs',
#    '4th',
#    'qtr',
#    '1985',
#    'extraordinary',
#    'loss',
#    '139,000',
#    'dlrs',
#    ',',
#    'five',
#    'cts',
#    'per',
#    'shr',
#    '.',
#    'for',
#    'year',
#    ',',
#    'include',
#    'extraordinary',
#    'credit',
#    '92,000',
#    'dlrs',
#    ',',
#    'three',
#    'cts',
#    'per',
#    'shr',
#    ',',
#    '1986',
#    '161,000',
#    'dlrs',
#    ',',
#    'five',
#    'cts',
#    'per',
#    'shr',
#    ',',
#    '1985',
#    '.'],
#   1),
#  (['potomac',
#    'electric',
#    'power',
#    'co',
#    '&',
#    'lt',
#    ';',
#    'pom',
#    '>',
#    'january',
#    'net',
#    'oper',
#    'shr',
#    '27',
#    'cts',
#    'vs',
#    '29',
#    'cts',
#    'oper',
#    'net',
#    '13.5',
#    'mln',
#    'vs',
#    '14.6',
#    'mln',
#    'revs',
#    '104.6',
#    'mln',
#    'vs',
#    '110.3',
#    'mln',
#    '12',
#    'mths',
#    'oper',
#    'shr',
#    '4.10',
#    'dlrs',
#    'vs',
#    '3.66',
#    'dlrs',
#    'oper',
#    'net',
#    '205',
#    'mln',
#    'vs',
#    '186.8',
#    'mln',
#    'revs',
#    '1.4',
#    'billion',
#    'vs',
#    '1.3',
#    'billion',
#    'note',
#    ':',
#    '1986',
#    '12',
#    'mths',
#    'oper',
#    'net',
#    'excludes',
#    'extraordinary',
#    'gain',
#    '21.7',
#    'mln',
#    'dlrs',
#    '46',
#    'cts',
#    'per',
#    'share',
#    'sale',
#    'virginia',
#    'service',
#    'territory',
#    'virginia',
#    'power',
#    '.'],
#   0),
#  (['gts',
#    'corp',
#    '&',
#    'lt',
#    ';',
#    'gtsc',
#    '>',
#    '4th',
#    'qtr',
#    'dec',
#    '31',
#    'loss',
#    'shr',
#    'loss',
#    '48',
#    'cts',
#    'vs',
#    'loss',
#    '10',
#    'cts',
#    'net',
#    'loss',
#    '1,234,000',
#    'vs',
#    'loss',
#    '259,000',
#    'revs',
#    '715,000',
#    'vs',
#    '1,941,000',
#    'year',
#    'shr',
#    'loss',
#    '1.26',
#    'dlrs',
#    'vs',
#    'loss',
#    '34',
#    'cts',
#    'net',
#    'loss',
#    '3,229,000',
#    'vs',
#    'loss',
#    '870,000',
#    'revs',
#    '3,001,000',
#    'vs',
#    '9,767,000',
#    'note',
#    ':',
#    '1986',
#    'net',
#    'periods',
#    'includes',
#    '672,300',
# ...
#    '.',
#    'the',
#    'one',
#    'dlr',
#    'increase',
#    'brings',
#    'west',
#    'texas',
#    'intermediate',
#    ',',
#    'wti',
#    'u.s.',
#    'benchmark',
#    'crude',
#    ',',
#    '17.00',
#    'dlrs',
#    'bbl',
#    ',',
#    'company',
#    'said',
#    '.',
#    'diamond',
#    'shamrock',
#    'joined',
#    'sun',
#    'co',
#    ',',
#    'coastal',
#    ',',
#    'citgo',
#    'murphy',
#    'oil',
#    'raising',
#    'crude',
#    'oil',
#    'posted',
#    'prices',
#    'one',
#    'dlr',
#    'barrel',
#    'yesterday',
#    '.'],
#   -1),
#  (['midland',
#    'bank',
#    'said',
#    'it',
#    'cutting',
#    'its',
#    'base',
#    'rate',
#    'to',
#    '10.5',
#    'pct',
#    'from',
#    '11',
#    'pct',
#    '.',
#    'midland',
#    'bank',
#    'said',
#    'it',
#    'cutting',
#    'its',
#    'base',
#    'rate',
#    'to',
#    '10.5',
#    'pct',
#    'from',
#    '11',
#    'pct',
#    '.'],
#   -1),
#  (['computer',
#    'terminal',
#    'systems',
#    '&',
#    'lt',
#    ';',
#    'cpml',
#    '>',
#    'completes',
#    'sale',
#    'computer',
#    'terminal',
#    'systems',
#    'inc',
#    'said',
#    'completed',
#    'sale',
#    '200,000',
#    'shares',
#    'common',
#    'stock',
#    ',',
#    'warrants',
#    'acquire',
#    'additional',
#    'one',
#    'mln',
#    'shares',
#    ',',
#    '&',
#    'lt',
#    ';',
#    'sedio',
#    'n.v.',
#    '>',
#    'lugano',
#    ',',
#    'switzerland',
#    '50,000',
#    'dlrs',
#    '.',
#    'the',
#    'company',
#    'said',
#    'warrants',
#    'exercisable',
#    'five',
#    'years',
#    'purchase',
#    'price',
#    '.125',
#    'dlrs',
#    'per',
#    'share',
#    '.',
#    'computer',
#    'terminal',
#    'said',
#    'sedio',
#    'also',
#    'right',
#    'buy',
#    'additional',
#    'shares',
#    'increase',
#    'total',
#    'holdings',
#    '40',
#    'pct',
#    'computer',
#    'terminal',
#    "'s",
#    'outstanding',
#    'common',
#    'stock',
#    'certain',
#    'circumstances',
#    'involving',
#    'change',
#    'control',
#    'company',
#    '.',
#    'the',
#    'company',
#    'said',
#    'conditions',
#    'occur',
#    'warrants',
#    'would',
#    'exercisable',
#    'price',
#    'equal',
#    '75',
#    'pct',
#    'common',
#    "stock's",
#    'market',
#    'price',
#    'time',
#    ',',
#    'exceed',
#    '1.50',
#    'dlrs',
#    'per',
#    'share',
#    '.',
#    'computer',
#    'terminal',
#    'also',
#    'said',
#    'sold',
#    'technolgy',
#    'rights',
#    'dot',
#    'matrix',
#    'impact',
#    'technology',
#    ',',
#    'including',
#    'future',
#    'improvements',
#    ',',
#    '&',
#    'lt',
#    ';',
#    'woodco',
#    'inc',
#    '>',
#    'houston',
#    ',',
#    'tex',
#    '.',
#    '200,000',
#    'dlrs',
#    '.',
#    'but',
#    ',',
#    'said',
#    'would',
#    'continue',
#    'exclusive',
#    'worldwide',
#    'licensee',
#    'technology',
#    'woodco',
#    '.',
#    'the',
#    'company',
#    'said',
#    'moves',
#    'part',
#    'reorganization',
#    'plan',
#    'would',
#    'help',
#    'pay',
#    'current',
#    'operation',
#    'costs',
#    'ensure',
#    'product',
#    'delivery',
#    '.',
#    'computer',
#    'terminal',
#    'makes',
#    'computer',
#    'generated',
#    'labels',
#    ',',
#    'forms',
#    ',',
#    'tags',
#    'ticket',
#    'printers',
#    'terminals',
#    '.'],
#   0),
#  (['assets',
#    'of',
#    'money',
#    'market',
#    'mutual',
#    'funds',
#    'rose',
#    '720.4',
#    'mln',
#    'dlrs',
#    'in',
#    'latest',
#    'week',
#    'assets',
#    'of',
#    'money',
#    'market',
#    'mutual',
#    'funds',
#    'rose',
#    '720.4',
#    'mln',
#    'dlrs',
#    'in',
#    'latest',
#    'week'],
#   1),
#  (['barclays',
#    ',',
#    'midland',
#    'follow',
#    'natwest',
#    'base',
#    'rate',
#    'cut',
#    'barclays',
#    'bank',
#    'plc',
#    '&',
#    'lt',
#    ';',
#    'bcs.l',
#    '>',
#    'midland',
#    'bank',
#    'plc',
#    '&',
#    'lt',
#    ';',
#    'mdbl.l',
#    '>',
#    'said',
#    'cutting',
#    'base',
#    'lending',
#    'rates',
#    '10.5',
#    'pct',
#    '11',
#    'pct',
#    '.',
#    'the',
#    'cuts',
#    'follow',
#    'similar',
#    'move',
#    'national',
#    'westminster',
#    'bank',
#    'plc',
#    '&',
#    'lt',
#    ';',
#    'nwbl.l',
#    '>',
#    'the',
#    'rate',
#    'changes',
#    'take',
#    'effect',
#    'tomorrow',
#    '.',
#    'the',
#    'base',
#    'rate',
#    'reductions',
#    'came',
#    'bank',
#    'england',
#    'cut',
#    'dealing',
#    'rates',
#    'morning',
#    'signal',
#    'money',
#    'markets',
#    'would',
#    'resist',
#    'half',
#    'percentage',
#    'point',
#    'drop',
#    'bank',
#    'base',
#    'lending',
#    'rates',
#    ',',
#    'market',
#    'sources',
#    'said',
#    '.',
#    'until',
#    'end',
#    'last',
#    'week',
#    ',',
#    'central',
#    'holding',
#    'staunchly',
#    'market',
#    'pressures',
#    'lower',
#    'rates',
#    'apparent',
#    'effort',
#    'preserve',
#    'expected',
#    'rate',
#    'cuts',
#    'around',
#    'time',
#    'government',
#    "'s",
#    'annual',
#    'budget',
#    'march',
#    '17',
#    '.',
#    'sterling',
#    'remained',
#    'firm',
#    'around',
#    '1.59',
#    'dlrs',
#    'compared',
#    'close',
#    'friday',
#    '1.5865',
#    'dlrs',
#    '.'],
#   -1),
#  (['&',
#    'lt',
#    ';',
#    'westar',
#    'mining',
#    'ltd',
#    '>',
#    '4th',
#    'qtr',
#    'loss',
#    'shr',
#    'given',
#    'oper',
#    'loss',
#    '5,900,000',
#    'vs',
#    'profit',
#    '9,300,000',
#    'revs',
#    '105.3',
#    'mln',
#    'vs',
#    '131.2',
#    'mln',
#    'year',
#    'shr',
#    'given',
#    'oper',
#    'loss',
#    '21.7',
#    'mln',
#    'vs',
#    'profit',
#    '34.7',
#    'mln',
#    'revs',
#    '370.7',
#    'mln',
#    'vs',
#    '515.1',
#    'mln',
#    'note',
#    ':',
#    '67',
#    'pct',
#    'owned',
#    '&',
#    'lt',
#    ';',
#    'british',
#    'columbia',
#    'resources',
#    'investment',
#    'corp',
#    '>',
#    'note',
#    'continued',
#    ':',
#    '1986',
#    'qtr',
#    'excludes',
#    'extraordinary',
#    'loss',
#    '3.6',
#    'mln',
#    'dlrs',
#    'versus',
#    'loss',
#    '294.0',
#    'mln',
#    'dlrs',
#    'prior',
#    'year',
#    '1986',
#    'year',
#    'excludes',
#    'extraordinary',
#    'loss',
#    '79.1',
#    'mln',
#    'dlrs',
#    'versus',
#    'loss',
#    '221.5',
#    'mln',
#    'dlrs',
#    'prior',
#    'year'],
#   1),
#  (['u.s.',
#    'bank',
#    'discount',
#    'borrowings',
#    'average',
#    '310',
#    'mln',
#    'dlrs',
#    'in',
#    'feb',
#    '25',
#    'week',
#    ',',
#    'fed',
#    'says',
#    'u.s.',
#    'bank',
#    'discount',
#    'borrowings',
#    'average',
#    '310',
#    'mln',
#    'dlrs',
#    'in',
#    'feb',
#    '25',
#    'week',
#    ',',
#    'fed',
#    'says'],
#   0),
#  (['usair',
#    '&',
#    'lt',
#    ';',
#    'u',
#    '>',
#    'has',
#    'no',
#    'comment',
#    'on',
#    'twa',
#    '&',
#    'lt',
#    ';',
#    'twa',
#    '>',
#    'offer',
#    'usair',
#    'group',
#    'inc',
#    'said',
#    'comment',
#    'offer',
#    'received',
#    'trans',
#    'world',
#    'airlines',
#    'buy',
#    'usair',
#    '52',
#    'dlrs',
#    'cash',
#    'per',
#    'share',
#    '.',
#    'usair',
#    'spokesman',
#    'david',
#    'shipley',
#    'also',
#    'declined',
#    'comment',
#    'piedmont',
#    'aviation',
#    'inc',
#    '&',
#    'lt',
#    ';',
#    'pie',
#    '>',
#    '.',
#    'usair',
#    'offered',
#    '71',
#    'dlrs',
#    'cash',
#    'per',
#    'share',
#    'half',
#    'piedmont',
#    "'s",
#    'stock',
#    ',',
#    '73',
#    'dlrs',
#    'stock',
#    'balance',
#    '.',
#    'piedmont',
#    'also',
#    'received',
#    'offer',
#    'norfolk',
#    'southern',
#    'corp',
#    '&',
#    'lt',
#    ';',
#    'nsc',
#    '>',
#    '65',
#    'dlrs',
#    'cash',
#    'per',
#    'share',
#    '.',
#    'piedmont',
#    "'s",
#    'board',
#    'meeting',
#    'today',
#    ',',
#    'company',
#    'declined',
#    'say',
#    'agenda',
#    '.',
#    'a',
#    'spokesman',
#    'said',
#    'could',
#    'comment',
#    'twa',
#    'action',
#    '.',
#    'a',
#    'norfolk',
#    'southern',
#    'corp',
#    '&',
#    'lt',
#    ';',
#    'nsc',
#    '>',
#    'spokesman',
#    'said',
#    'company',
#    'comment',
#    'twa',
#    "'s",
#    'offer',
#    'usair',
#    'proposal',
#    'negotiate',
#    'three-way',
#    'merger',
#    'twa',
#    ',',
#    'usair',
#    'piedmont',
#    '.',
#    '``',
#    'we',
#    "n't",
#    'details',
#    ',',
#    "''",
#    'norfolk',
#    'southern',
#    'spokesman',
#    'said',
#    '.',
#    'the',
#    'company',
#    "'s",
#    '65',
#    'dlr-a-share',
#    'cash',
#    'offer',
#    'piedmont',
#    'stands',
#    ',',
#    'said',
#    '.',
#    'in',
#    'offer',
#    ',',
#    'twa',
#    'said',
#    'alternative',
#    'merger',
#    'usair',
#    ',',
#    'would',
#    'interested',
#    'discussing',
#    'three-way',
#    'combination',
#    'among',
#    'usair',
#    ',',
#    'piedmont',
#    'twa',
#    '.',
#    'it',
#    'said',
#    'three-way',
#    'merger',
#    'would',
#    'serve',
#    'best',
#    'interests',
#    'shareholders',
#    'three',
#    'companies',
#    ',',
#    'employees',
#    'consumers',
#    '.'],
#   1),
#  (['am',
#    'international',
#    '&',
#    'lt',
#    ';',
#    'am',
#    '>',
#    'cites',
#    'strong',
#    'prospects',
#    'am',
#    'international',
#    'inc',
#    ',',
#    'reporting',
#    'operating',
#    'loss',
#    'january',
#    '31',
#    'second',
#    'quarter',
#    ',',
#    'said',
#    'prospects',
#    'balance',
#    'fiscal',
#    'year',
#    'remain',
#    'good',
#    '.',
#    'it',
#    'said',
#    'orders',
#    'harris',
#    'graphics',
#    'subsidiary',
#    ',',
#    'acquired',
#    'june',
#    '1986',
#    ',',
#    '``',
#    'continue',
#    'run',
#    'strong',
#    'pace',
#    '.',
#    "''",
#    'for',
#    'six',
#    'months',
#    ',',
#    'orders',
#    'rose',
#    '35',
#    'pct',
#    'corresponding',
#    'prior-year',
#    'period',
#    ',',
#    'annualized',
#    'basis',
#    'running',
#    '630',
#    'mln',
#    'dlrs',
#    '.',
#    'the',
#    'backlog',
#    'harris',
#    '30',
#    'pct',
#    'beginning',
#    'fiscal',
#    'year',
#    ',',
#    'am',
#    'said',
#    '.',
#    'am',
#    'international',
#    'said',
#    'old',
#    'division',
#    'expected',
#    'benefit',
#    'recent',
#    'new',
#    'product',
#    'introductions',
#    'decline',
#    'value',
#    'dollar',
#    '.',
#    '``',
#    'research',
#    ',',
#    'development',
#    'engineering',
#    'expenditures',
#    'fiscal',
#    '1987',
#    '45-50',
#    'mln',
#    'dlr',
#    'range',
#    ',',
#    'company',
#    'said',
#    'allocated',
#    'another',
#    '30-40',
#    'mln',
#    'dlrs',
#    'capital',
#    'expenditures',
#    '.',
#    'earlier',
#    'am',
#    'reported',
#    'fourth',
#    'quarter',
#    'operating',
#    'loss',
#    'two',
#    'cts',
#    'share',
#    'compared',
#    'profits',
#    'seven',
#    'cts',
#    'share',
#    'year',
#    'ago',
#    '.',
#    'revenues',
#    'rose',
#    '291.8',
#    'mln',
#    'dlrs',
#    '151.1',
#    'mln',
#    'dlrs',
#    '.'],
#   1),
#  (['texon',
#    'energy',
#    '&',
#    'lt',
#    ';',
#    'txon',
#    '>',
#    'in',
#    'talks',
#    'on',
#    'acquisition',
#    'texon',
#    'energy',
#    'corp',
#    'said',
#    'entered',
#    'preliminary',
#    'agreement',
#    'purchase',
#    '80',
#    'pct',
#    'interest',
#    'privately-held',
#    'specialty',
#    'plastics',
#    'manufacturing',
#    'company',
#    'name',
#    '.',
#    'texon',
#    'said',
#    'completion',
#    'acquisition',
#    'subject',
#    'consent',
#    'banks',
#    'third',
#    'parties',
#    'acquisition',
#    'would',
#    'made',
#    'promissory',
#    'notes',
#    'common',
#    'stock',
#    '.'],
#   -1),
#  (['waste',
#    'management',
#    'says',
#    'waiting',
#    'period',
#    'ends',
#    'on',
#    'its',
#    'chemlawn',
#    'bid',
#    'waste',
#    'management',
#    'says',
#    'waiting',
#    'period',
#    'ends',
#    'on',
#    'its',
#    'chemlawn',
#    'bid'],
#   -1),
#  (['vereins-',
#    'und',
#    'westbank',
#    'to',
#    'reorganize',
#    'network',
#    'und',
#    'westbank',
#    'ag',
#    '&',
#    'lt',
#    ';',
#    'vhbg.f',
#    '>',
#    'plans',
#    'streamline',
#    'branch',
#    'network',
#    'improve',
#    'distribution',
#    'financial',
#    'services',
#    ',',
#    'management',
#    'board',
#    'member',
#    'eberhard-rainer',
#    'luckey',
#    'said',
#    '.',
#    'he',
#    'told',
#    'news',
#    'conference',
#    '1986',
#    'results',
#    'branches',
#    'hamburg',
#    'schleswig-holstein',
#    'would',
#    'merged',
#    'closed',
#    ',',
#    'branch',
#    'frankfurt',
#    'opened',
#    'bank',
#    'considering',
#    'opening',
#    'branch',
#    'london',
#    '.',
#    'luckey',
#    'said',
#    'bank',
#    "'s",
#    'total',
#    'operating',
#    'profits',
#    'rose',
#    'nearly',
#    '29',
#    'pct',
#    '1986',
#    '.',
#    'parent',
#    'bank',
#    'net',
#    'profit',
#    'rose',
#    '47.7',
#    'mln',
#    '42.2',
#    'mln',
#    'dividend',
#    'remained',
#    'unchanged',
#    '12',
#    'marks',
#    '.',
#    'the',
#    'group',
#    'balance',
#    'sheet',
#    ',',
#    'including',
#    'first',
#    'time',
#    'vereinwest',
#    'overseas',
#    'finance',
#    '(',
#    'jersey',
#    ')',
#    ',',
#    'rose',
#    '9.2',
#    'pct',
#    '17.9',
#    'billion',
#    'marks',
#    ',',
#    'luckey',
#    'said',
#    '.',
#    'the',
#    'parent',
#    'bank',
#    'balance',
#    'sheet',
#    'rose',
#    '89',
#    'mln',
#    'marks',
#    '13.2',
#    'billion',
#    ',',
#    'business',
#    'volume',
#    'almost',
#    'unchanged',
#    '14.8',
#    'billion',
#    '.',
#    'credit',
#    'volume',
#    'eased',
#    '9.1',
#    'billion',
#    '9.2',
#    'billion',
#    'loans',
#    'companies',
#    'rose',
#    'seven',
#    'pct',
#    '.',
#    'foreign',
#    'business',
#    'securities',
#    'trading',
#    'turnover',
#    'also',
#    'increased',
#    '.',
#    'higher',
#    'earnings',
#    'trading',
#    'bank',
#    "'s",
#    'account',
#    'contributed',
#    'record',
#    'operating',
#    'profits',
#    '.',
#    'net',
#    'interest',
#    'income',
#    'rose',
#    'firmer',
#    'interest',
#    'margins',
#    '16.1',
#    'mln',
#    'marks',
#    '381.6',
#    'mln',
#    '.',
#    'net',
#    'commission',
#    'income',
#    'rose',
#    '6.6',
#    'mln',
#    '156.7',
#    'mln',
#    ',',
#    'luckey',
#    'said',
#    '.',
#    'foreign',
#    'commercial',
#    'business',
#    'influenced',
#    'fall',
#    'west',
#    'german',
#    'foreign',
#    'trade',
#    'earnings',
#    'still',
#    'satisfactory',
#    '.',
#    'the',
#    'bank',
#    "'s",
#    'exposure',
#    'latin',
#    'america',
#    'less',
#    'two',
#    'pct',
#    'total',
#    'foreign',
#    'credit',
#    'africa',
#    'less',
#    'one',
#    'pct',
#    '.',
#    'the',
#    'bank',
#    'continued',
#    'sell',
#    'exposure',
#    '1986',
#    ',',
#    'also',
#    'continue',
#    'stock',
#    'risk',
#    'provisions',
#    ',',
#    'said',
#    '.'],
#   1),
#  (['investment',
#    'group',
#    'raises',
#    'robeson',
#    '&',
#    'lt',
#    ';',
#    'rbsn',
#    '>',
#    'stake',
#    'a',
#    'group',
#    'affiliated',
#    'miami-based',
#    'investment',
#    'firms',
#    'led',
#    'fundamental',
#    'management',
#    'corp',
#    'said',
#    'raised',
#    'stake',
#    'robeson',
#    'industries',
#    'corp',
#    '238,000',
#    'shares',
#    ',',
#    '14.6',
#    'pct',
#    'total',
#    ',',
#    '205,000',
#    '12.8',
#    'pct',
#    '.',
#    'in',
#    'filing',
#    'securities',
#    'exchange',
#    'commission',
#    ',',
#    'group',
#    'said',
#    'bought',
#    '32,800',
#    'robeson',
#    'common',
#    'shares',
#    'jan',
#    '26',
#    'feb',
#    '9',
#    '175,691',
#    'dlrs',
#    '.',
#    'the',
#    'group',
#    'said',
#    'may',
#    'buy',
#    'shares',
#    'plans',
#    'study',
#    'robeson',
#    "'s",
#    'operations',
#    '.',
#    'afterwards',
#    'may',
#    'recommend',
#    'management',
#    'make',
#    'changes',
#    'operations',
#    '.',
#    'fundamental',
#    'management',
#    'chairman',
#    'carl',
#    'singer',
#    'recently',
#    'elected',
#    'robeson',
#    'board',
#    '.'],
#   0),
#  (['commonwealth',
#    'mortgage',
#    '&',
#    'lt',
#    ';',
#    'ccmc',
#    '>',
#    'buys',
#    'armonk',
#    'firm',
#    'commonwealth',
#    'mortgage',
#    'co',
#    'said',
#    'purchased',
#    'westfiar',
#    'funding',
#    'corp',
#    'armonk',
#    ',',
#    'n.y.',
#    ',',
#    'undisclosed',
#    'amount',
#    'cash',
#    '.',
#    'commonwealth',
#    'said',
#    'westfair',
#    'originated',
#    '60',
#    'mln',
#    'dlrs',
#    'residential',
#    'mortgage',
#    'loans',
#    '1986',
#    '.'],
#   -1),
#  (['s',
#    '&',
#    'amp',
#    ';',
#    'l',
#    'acquisition',
#    'raises',
#    'u.s.',
#    '1987',
#    'toll',
#    'to',
#    '12',
#    'the',
#    'federal',
#    'home',
#    'loan',
#    'bank',
#    'board',
#    '(',
#    'fhlbb',
#    ')',
#    'announced',
#    'acquisition',
#    'home',
#    'savings',
#    'loan',
#    'association',
#    'seattle',
#    ',',
#    'washington',
#    ',',
#    'interwest',
#    'savings',
#    'bank',
#    'oak',
#    'harbour',
#    ',',
#    'washington',
#    '.',
#    'the',
#    'fhlbb',
#    'said',
#    'home',
#    'savings',
#    '12th',
#    'troubled',
#    'savings',
#    'institution',
#    'requiring',
#    'federal',
#    'action',
#    'year',
#    '.',
#    'it',
#    'said',
#    'home',
#    'savings',
#    'assets',
#    '150.6',
#    'mln',
#    'dlrs',
#    'assets',
#    'interwest',
#    'assets',
#    '342.9',
#    'mln',
#    'dlrs',
#    '.'],
#   -1)]

# %%
all_words = []
for i in documents:
    all_words+=i[0]

# %%
import nltk
all_words = nltk.FreqDist(all_words)
word_features = list(all_words.keys())[:3000]

print(all_words)
print(word_features)

def feature_extractor(review):
  words = set(review)
  features = {}
  for w in word_features:
    features[w] = (w in words)
  return features

featureset = [(feature_extractor(review),sentiment) 
              for (review, sentiment) in documents]
# Out:
# <FreqDist with 5141 samples and 25984 outcomes>
# ['foote', 'mineral', '&', 'lt', ';', 'fte', '>', 'sells', 'cambridge', 'plant', 'co', 'said', 'signed', 'letter', 'intent', 'shieldalloy', 'corp', ',', 'wholly-owned', 'subsidiary', 'metallurg', 'inc', 'sale', 'ohio', 'business', '.', 'the', 'company', 'explained', 'greater', 'detail', 'definitive', 'agreement', 'part', "'s", 'previously-announced', 'plan', 'sell', 'entire', 'cantrex', 'unit', 'to', 'merge', 'with', 'ontario', 'group', '(', 'groupe', ')', 'plans', 'new', 'merger', 'cap', 'appliance', 'purchasers', 'woodstock', '400', 'electronics', 'retailers', 'it', 'shareholders', 'receive', '140,700', 'first', 'preferred', 'shares', 'entitling', 'holders', '6.05', 'dlrs', 'per', 'share', 'equivilant', 'class', 'a', 'subordinate', 'voting', 'effective', 'april', 'one', 'subject', 'shareholder', 'approval', 'handy', 'and', 'harman', 'hnh', '4th', 'qtr', 'loss', 'shr', '51', 'cts', 'vs', 'three', 'net', '7,041,000', '467,000', 'rev', '138.9', 'mln', '131.4', '12', 'months', '64', 'profit', '46', '8,843,000', '6,306,0000', '558.9', '556.7', 'note', ':', '1986', 'includes', 'charge', 'restructuring', '2.6', 'tax', '19', 'special', '2.7', '20', 'northern', 'telecom', 'ltd', 'nt', 'declares', 'stock', 'split', 'two-for-one', 'pay', 'may', '23', 'annual', 'meeting', 'also', 'increase', 'dividend', 'post-split', 'six', 'five', 'api', 'says', 'distillate', 'stocks', 'off', '4.4', 'bbls', 'gasoline', '30,000', 'crude', 'up', '700,000', 'united', 'presidential', 'upco', '39', '50', '1,545,160', '2,188,933', 'revs', '25.2', '19.5', 'year', '1.53', '1.21', '6,635,318', '5,050,044', '92.2', '77.4', 'results', 'include', 'adjustment', '848,600', '1985', 'periods', 'improvement', 'universal', 'life', 'estimated', 'ivaco', 'sees', 'minimal', 'quarter', 'earnings', 'price', 'pressure', 'steel', 'products', 'particularly', 'u.s.', 'recent', 'value', 'canadian', 'dollar', 'expected', 'result', '``', "''", 'subsequent', 'quarters', 'show', 'substantial', 'levels', '1987', 'reach', 'long', 'conditions', 'continue', 'earlier', 'reported', 'rose', '44.1', 'dlr', 'extraordinary', 'gain', '35.1', 'previous', 'demand', 'continuing', 'high', 'sales', 'growth', 'revenues', 'last', '1.94', 'billion', '1.34', 'piedmont', 'aviation', 'pie', 'board', 'meet', 'today', 'avaition', 'directors', 'conduct', 'beginning', '1400', 'est', 'spokesman', 'would', 'say', 'agenda', 'in', 'mid-february', 'discuss', 'proposals', 'acquire', 'its', 'withdrew', 'recommendation', 'accept', '65', 'cash', 'offer', 'norfolk', 'southern', 'nsc', 'light', 'competing', 'revised', 'bid', 'air', 'u', 'buy', 'pct', '71', 'remaining', '73', 'calmar', 'clmi', 'seeks', 'be', 'acquired', 'by', 'kebo', 'ab', 'keboo', 'sweden', 'owns', 'calmark', 'approved', 'acquisition', '25.375', 'request', 'held', 'march', 'nine', 'form', 'committee', 'affiliated', 'evaluate', 'transaction', 'turn', '60', 'owned', 'investment', 'beijar', '26-feb-1987', 'wallace', 'computer', 'services', 'wcs', 'qtly', 'div', '15', 'previously', 'june', 'record', 'philippine', 'distance', 'phi', 'primary', '95.30', 'pesos', '29.71', 'diluted', '61.11', '18.49', '1.25', '1.9', '779', '6.1', '4.7', 'full', 'name', 'telephone', 'figures', 'quoted', 'payable', '13', 'exchange', 'rate', 'day', 'declaration', '20.792', 'scott', 'hospitality', 'acquires', 'capital', 'food', 'issued', 'ottawa', 'terms', 'disclosed', 'operate', 'present', 'existing', 'management', 'provides', 'several', 'institutions', 'alatenn', 'resources', 'atng', '75', '52', '1,699,124', '1,177,786', '45.6', '31.6', 'mths', '2.22', '2.20', '5,057,292', '4,961,085', '130.2', '126.7', 'malaysia', 're-imposes', 'export', 'duties', 'on', 'rubber', 'malaysian', 'government', 're-imposed', '3/8', 'cent', 'kilo', 'gazetted', 'moved', 'threshold', '210', 'cents', '1', '213-1/2', 'february', '207', 'duty', 'research', 'remains', '3.85', 'replanting', 'unchanged', '9.92', 'gao', 'likely', 'certs', 'more', 'costly', 'than', 'study', 'grain', 'certificates', 'due', 'short ...

# %%
training_set, testing_set = featureset[:1900],featureset[1900:]
training_set, testing_set = featureset[:200],featureset[200:]

# %%
classifier_challenge = nltk.NaiveBayesClassifier.train(training_set)
print("Classifier accuracy:", nltk.classify.accuracy(classifier_challenge, testing_set))
classifier_challenge.show_most_informative_features(15)
# Out:
# Classifier accuracy: 0.64
# Most Informative Features
#                    crude = True               -1 : 0      =     15.9 : 1.0
#                      net = True                0 : -1     =     12.8 : 1.0
#                  billion = True                1 : -1     =     11.6 : 1.0
#                      shr = True                0 : -1     =     11.5 : 1.0
#                     revs = True                0 : -1     =      9.5 : 1.0
#                      4th = True                0 : -1     =      8.9 : 1.0
#                      qtr = True                0 : -1     =      8.9 : 1.0
#                     rose = True                1 : 0      =      7.5 : 1.0
#                     week = True               -1 : 1      =      7.4 : 1.0
#                 december = True                1 : -1     =      7.2 : 1.0
#                     base = True               -1 : 0      =      7.1 : 1.0
#                      div = True                0 : -1     =      6.9 : 1.0
#                    prior = True                0 : 1      =      6.6 : 1.0
#                      new = True                1 : -1     =      6.6 : 1.0
#                        , = False               0 : 1      =      6.4 : 1.0

# %% [markdown]
# https://www.datacamp.com/community/tutorials/text-analytics-beginners-nltk

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import RegexpTokenizer
#tokenizer to remove unwanted elements from out data like symbols and numbers
token = RegexpTokenizer(r'[a-zA-Z0-9]+')
cv = CountVectorizer(lowercase=True,stop_words='english',ngram_range = (1,1),tokenizer = token.tokenize)
#lower(word_tokenize(df.iloc[i]["Text"]))
text_counts= cv.fit_transform(df['Text'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    text_counts, df['Sentiments'], test_size=0.3, random_state=1)

# %%
from sklearn.naive_bayes import MultinomialNB
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Generation Using Multinomial Naive Bayes
clf = MultinomialNB().fit(X_train, y_train)
predicted= clf.predict(X_test)
print("MultinomialNB Accuracy:",metrics.accuracy_score(y_test, predicted))
# Out:
# MultinomialNB Accuracy: 0.6

# %%
X_test
# Out:
# <90x4166 sparse matrix of type '<class 'numpy.int64'>'
# 	with 4068 stored elements in Compressed Sparse Row format>

# %%
token = RegexpTokenizer(r'[a-zA-Z0-9]+')
cv = CountVectorizer(lowercase=True,stop_words='english',ngram_range = (1,1),tokenizer = token.tokenize)
#lower(word_tokenize(df.iloc[i]["Text"]))
text= cv.fit_transform(["Trump has once against caused a major dispute among countries"])
text#clf.predict(text)
# Out:
# <1x5 sparse matrix of type '<class 'numpy.int64'>'
# 	with 5 stored elements in Compressed Sparse Row format>

# %% [markdown]
# https://towardsdatascience.com/natural-language-processing-count-vectorization-with-scikit-learn-e7804269bb5e

# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer

from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics

# Create our vectorizer
vectorizer = CountVectorizer()

# All data
newsgroups_train = fetch_20newsgroups(subset='train',
                                      remove=('headers', 'footers', 'quotes'))
newsgroups_test = fetch_20newsgroups(subset='test',
                                     remove=('headers', 'footers', 'quotes'))

# Get the training vectors
vectors = vectorizer.fit_transform(newsgroups_train.data)

# Build the classifier
clf = MultinomialNB(alpha=.01)

#  Train the classifier
clf.fit(vectors, newsgroups_train.target)

# Get the test vectors
vectors_test = vectorizer.transform(newsgroups_test.data)

# Predict and score the vectors
pred = clf.predict(vectors_test)
acc_score = metrics.accuracy_score(newsgroups_test.target, pred)
f1_score = metrics.f1_score(newsgroups_test.target, pred, average='macro')

print('Total accuracy classification score: {}'.format(acc_score))
print('Total F1 classification score: {}'.format(f1_score))
# Out:
# Downloading 20news dataset. This may take a few minutes.
# Downloading dataset from https://ndownloader.figshare.com/files/5975967 (14 MB)
# Total accuracy classification score: 0.6460435475305364
# Total F1 classification score: 0.6203806145034193
