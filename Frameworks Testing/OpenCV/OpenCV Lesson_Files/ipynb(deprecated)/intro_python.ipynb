# %%
# Define a string 'Who here is familiar with Python?' as message.
message = _______________

# %%
# Print the message to display its contents.
_____(message)

# %%
# Assign the integer value of 4 to a variable named RAM.
___ = _

# Verify that RAM is an integer.
print(type(RAM))

# %%
# Assign the floating point number of 1.5 to a variable named CPU_GHZ.
______ = ___

# Verify that CPU_GZH is a float.
print(type(CPU_GHZ))

# %%
# Now, put all of the above into an array(list) with two other data you want to add.
my_array = _______________

# Print out my_array to view its contents
print(my_array)
