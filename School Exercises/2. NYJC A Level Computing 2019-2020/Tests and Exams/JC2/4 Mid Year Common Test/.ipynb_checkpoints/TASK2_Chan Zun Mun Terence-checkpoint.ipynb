# %%
#Task 2.1

import random
def displayInRows(array, sets=10):
    output = ""
    for index in range(len(array)):
        output += f"{array[index]}"
        index += 1
        if index % sets == 0:
            output += '\n'
        else:
            output += ' '
        
    output = output.strip() # Remove any trailing newline/ spaces
    print(output)
    
def driver():
    ### Create an array of 50 random integers
    array = [] # Python list simulates an array
    for i in range(50):
        array.append(random.randint(0,99)) # Inclusive
        
    print()
    print("Original array:")
    displayInRows(array)
    
    print()
    print("Sorted array:")
    sortedArray = MergeSort(array)  
    displayInRows(sortedArray)

### Merge Sort ##########################################
def cmp(order, a, b):
    if order == 'A':
        return a < b
    else:
        return a > b

def merge(left, right, order='A'):
    result = []
    l = 0 # Index of left array
    r = 0 # Index of right array
    while l + r < len(left) + len(right):
        bothIndexesInRange = l < len(left) and r < len(right)
        if (bothIndexesInRange and cmp(order, left[l],right[r])) or \
            r >= len(right):
            result.append(left[l])
            l += 1
        else:
            result.append(right[r])
            r += 1
    return result

def MergeSort(array):
    # Base case
    if len(array) <= 1: # Already sorted
        return array
    else:
        # Divide
        mid = len(array) // 2
        left = array[:mid]
        right = array[mid:]
        
        # Sort
        left = MergeSort(left)
        right = MergeSort(right)
        
        # Merge
        return merge(left, right)
########################################################

driver()
# Out:
# Original array:
# 23 51 57 3 88 81 43 26 68 25
# 31 58 54 13 18 75 27 86 74 9
# 65 38 50 98 9 10 2 70 96 14
# 88 86 46 37 89 45 83 34 68 33
# 55 17 0 84 89 30 97 25 75 84
#
# Sorted array:
# 0 2 3 9 9 10 13 14 17 18
# 23 25 25 26 27 30 31 33 34 37
# 38 43 45 46 50 51 54 55 57 58
# 65 68 68 70 74 75 75 81 83 84
# 84 86 86 88 88 89 89 96 97 98

# %%
#Task 2.2

### Other Code #########################################

import random
def displayInRows(array, sets=10):
    output = ""
    for index in range(len(array)):
        output += f"{array[index]}"
        index += 1
        if index % sets == 0:
            output += '\n'
        else:
            output += ' '
        
    output = output.strip() # Remove any trailing newline/ spaces
    print(output)

## From previous merge sort ###
def cmp(order, a, b):
    if order == 'A':
        return a < b
    else:
        return a > b

def merge(left, right, order='A'):
    result = []
    l = 0 # Index of left array
    r = 0 # Index of right array
    while l + r < len(left) + len(right):
        bothIndexesInRange = l < len(left) and r < len(right)
        if (bothIndexesInRange and cmp(order, left[l],right[r])) or \
            r >= len(right):
            result.append(left[l])
            l += 1
        else:
            result.append(right[r])
            r += 1
    return result

### New Merge Sort Code ######################################
def MergeSortPass(Array, sz, SortOrder): # Working
    # Sort the smaller subarrays
    index = 0
    while index < len(Array):
        low = index
        mid = index + sz
        high = index + 2 * sz
        #print(low, mid, high, index) # Debugging

        left = Array[low:mid]
        right = Array[mid:high]

        result = merge(left, right, SortOrder)
        for index in range(len(result)):
            Array[low + index] = result[index] 

        index = high # Sort the next subarray
        
def MergesortLoop(Array, SortOrder):
    sz = 1 # Size of subarray to sort
    while sz < len(Array):
        print(Array, sz)
        MergeSortPass(Array, sz, SortOrder)
            
        sz *= 2
    return Array

### New driver which allows specifying sort order #################
def driver():
    print("Choose sort order")
    SortOrder = input("Enter 'A' for Ascending, 'D' for Descending: ")
    print() 
    
    ### Create an array of 50 random integers
    array = [] # Python list simulates an array
    for i in range(50):
        array.append(random.randint(0,99)) # Inclusive
        
    print()
    print("Original array:")
    displayInRows(array)
    
    print()
    print("Sorted array:")
    sortedArray = MergesortLoop(array, SortOrder)  
    displayInRows(sortedArray)

# %% [markdown]
# ### Task 2.2
#
# Test cases for `MergesortLoop(Array, SortOrder)`
#
# Test Case (Input) | Purpose | Expected Output
# --|--|--
# [] , 'D'| Extreme Case (No Elements at all) | []
# [7, 8, 3, 3, 4, 8, 5, 7, 8, 4] , 'A' | Normal Case | [3, 3, 4, 4, 5, 7, 7, 8, 8, 8]

# %%
### Task 2.2 Testing
print(MergesortLoop([3, 3, 4, 4, 5, 7, 7, 8, 8, 8], 'A'))
# Out:
# [3, 3, 4, 4, 5, 7, 7, 8, 8, 8] 1
# 0 1 2 0
# 2 3 4 2
# 4 5 6 4
# 6 7 8 6
# 8 9 10 8
# [3, 3, 4, 4, 5, 7, 7, 8, 8, 8] 2
# 0 2 4 0
# 4 6 8 4
# 8 10 12 8
# [3, 3, 4, 4, 5, 7, 7, 8, 8, 8] 4
# 0 4 8 0
# 8 12 16 8
# [3, 3, 4, 4, 5, 7, 7, 8, 8, 8] 8
# 0 8 16 0
# [3, 3, 4, 4, 5, 7, 7, 8, 8, 8]
