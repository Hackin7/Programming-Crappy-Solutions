# %%
## Task 1.1
import pymongo
def clear():
    conn = pymongo.MongoClient('127.0.0.1', 27017)
    db = conn.get_database("IUCN")
    db.drop_collection("red")
    conn.drop_database("IUCN")
    conn.close()

clear()
conn = pymongo.MongoClient('127.0.0.1', 27017)
db = conn.get_database("IUCN")
coll = db.get_collection("red")

#conn.close()

# %%
## Task 1.2

import csv
def readtoDB(coll, filename="statistic_by_country.txt"):
    file = open(filename, 'r') # Read mode
    header = None
    for line in file:
        if header != None:
            record = line.strip().split(",")
            data = {
                "ID": record[0], 
                "Country": record[1], 
                "Region":record[2]
                "EX": record[3],
                "EW":record[4],
                "CR":record[5],
                "EN":record[6],
                "VU":record[7],
                "NT":record[8],
                "LRCD":record[9],
                "DD":record[10],
                "LC":record[11]
            }
            coll.insert_one(data)
    file.close()

readtoDB(coll)

# %%
## Task 1.3
# Initialisation code
import pymongo
conn = pymongo.MongoClient('127.0.0.1', 27017)
db = conn.get_database("IUCN")
coll = db.get_collection("red")

header = ["ID","Country","Region","EX","EW","CR","EN","VU","NT","LRCD","DD","LC"]
spacing = [10,30,30,10,10,10,10,10,10,10,10,10,10]
keys = ["ID","Country","Region","EX","EW","CR","EN","VU","NT","LRCD","DD","LC"]

## Displaying query
def show(coll, query, header, spacing, keys):
    cursor = coll.find(query)
    #print(cursor)
    output = ""
    for index in range(len(header)):
            output += f"{header[index]:<{spacing[index]}}"
    for record in cursor:
        output += "\n"
        for index in range(len(keys)):
            key = keys[index]
            output += f"{record[key]:<{spacing[index]}}"
    print(output)

# The actual query
query = {
    "$or":[
        {"Region":"Sub-Saharan Africa"}, 
        {"Region":"East Asia"}
    ]
}
show(coll, query, header, spacing, keys)
show(coll, {}, header, spacing, keys)
# Out:
# ID        Country                       EX                            EW        CR        EN        VU        LRCD      DD        LC
# ID        Country                       EX                            EW        CR        EN        VU        LRCD      DD        LC
# ##id       county                        region                        EX        EW        CR        EN        VU        NT        LRCD
# 1         Algeria                       North Africa                  2         1         17        38        72        58        0
# 2         Egypt                         North Africa                  1         1         14        28        122       136       2
# 3         Libya                         North Africa                  0         1         10        16        41        28        0
# 4         Morocco                       North Africa                  2         0         29        59        89        81        0
# 5         Tunisia                       North Africa                  11        0         15        24        56        48        0
# 6         Western Sahara                North Africa                  0         1         6         18        34        32        0
# 7         Angola                        Sub-Saharan Africa            0         0         15        36        77        61        0
# 8         Benin                         Sub-Saharan Africa            0         0         15        19        51        49        0
# 9         Botswana                      Sub-Saharan Africa            0         0         4         7         19        29        0
# 10        Burkina Faso                  Sub-Saharan Africa            0         1         7         6         18        22        0
# 11        Burundi                       Sub-Saharan Africa            0         0         6         15        33        39        0
# 12        Cabo Verde                    Sub-Saharan Africa            1         0         9         21        38        31        0
# 13        Cameroon                      Sub-Saharan Africa            0         0         64        107       127       82        0
# 14        Central African Republic      Sub-Saharan Africa            0         0         9         9         26        27        0
# 15        Chad                          Sub-Saharan Africa            0         1         11        5         26        21        0
# 16        Comoros                       Sub-Saharan Africa            0         0         7         27        84        109       0
# 17        Congo                         Sub-Saharan Africa            0         0         10        22        67        46        0
# 18        Congo The Democratic Republic of the CongoSub-Saharan Africa            0         0         31        75        151       93        0
# 19        C̫te d'Ivoire                Sub-Saharan Africa            0         0         20        38        89        91        0
# 20        Djibouti                      Sub-Saharan Africa            0         0         11        14        82        124       0
# 21        Equatorial Guinea             Sub-Saharan Africa            0         0         15        30        53        41        0
# 22        Eritrea                       Sub-Saharan Africa            0         0         16        21        100       138       0
# 23        Eswatini                      Sub-Saharan Africa            0         0         4         6         18        22        0
# 74        Ukraine                       North Asia                    2         0         11        25        55        68        0
# 75        Bangladesh                    South & Southeast Asia        0         1         29        42        69        79        0
# 76        Bhutan                        South & Southeast Asia        0         0         7         15        34        41        0
# 77        British Indian Ocean TerritorySouth & Southeast Asia        0         0         3         12        75        104       2
# 78        Brunei Darussalam             South & Southeast Asia        0         0         13        29        73        126       0
# 79        Cambodia                      South & Southeast Asia        0         0         33        51        155       170       0
# 80        Disputed Territory            South & Southeast Asia        0         0         1         3         9         3         0
# 81        India                         South & Southeast Asia        0         0         90        212       386       327       2
# 82        Indonesia                     South & Southeast Asia        3         0         152       270       605       607       4
# 83        Lao People's Democratic RepublicSouth & Southeast Asia        1         0         33        52        102       94        0
# 84        Malaysia                      South & Southeast Asia        1         0         91        158       416       424       3
# 85        Maldives                      South & Southeast Asia        0         0         6         16        58        92        2
# 86        Myanmar                       South & Southeast Asia        0         0         38        71        168       262       3
# 87        Nepal                         South & Southeast Asia        0         0         13        23        53        67        0
# 88        Philippines                   South & Southeast Asia        0         0         58        164       394       343       5
# 89        Singapore                     South & Southeast Asia        1         0         21        38        201       230       3
# 90        Sri Lanka                     South & Southeast Asia        20        0         81        120       142       174       2
# 91        Thailand                      South & Southeast Asia        2         0         57        104       331       367       2
# 92        Timor-Leste                   South & Southeast Asia        0         0         8         13        15        34        0
# 93        Viet Nam                      South & Southeast Asia        1         0         70        136       272       253       2
# 94        Afghanistan                   West & Central Asia           0         0         4         8         23        27        0
# 95        Armenia                       West & Central Asia           0         0         6         9         28        38        0
# 96        Azerbaijan                    West & Central Asia           0         1         13        10        33        41        0
# 97        Bahrain                       West & Central Asia           0         0         10        9         28        53        0
# 98        Cyprus                        West & Central Asia           0         0         9         19        32        38        0
# 99        Georgia                       West & Central Asia           0         0         7         10        40        46        0
# 100       Iran Islamic Republic of      West & Central Asia           0         1         23        35        91        100       0
# 101       Iraq                          West & Central Asia           0         0         12        14        50        69        0
# 102       Israel                        West & Central Asia           3         0         22        40        117       136       0
# 103       Jordan                        West & Central Asia           0         0         4         23        86        117       0
# 104       Kazakhstan                    West & Central Asia           0         1         14        13        39        38        0
# 105       Kuwait                        West & Central Asia           1         0         8         12        37        56        0
# 106       Kyrgyzstan                    West & Central Asia           0         0         1         7         22        24        0
# 107       Lebanon                       West & Central Asia           0         0         8         25        47        41        0
# 108       Oman                          West & Central Asia           0         0         12        28        66        92        0
# 109       Pakistan                      West & Central Asia           0         0         20        38        84        97        0
# 110       Palestine State of            West & Central Asia           0         0         3         11        15        23        0
# 111       Qatar                         West & Central Asia           0         0         11        7         32        55        0
# 112       Saudi Arabia                  West & Central Asia           1         0         13        27        100       141       2
# 113       Syrian Arab Republic          West & Central Asia           1         0         17        34        64        52        0
# 114       Tajikistan                    West & Central Asia           0         0         3         7         25        20        0
# 115       Turkey                        West & Central Asia           4         0         68        104       125       104       0
# 116       Turkmenistan                  West & Central Asia           0         1         11        12        32        28        0
# 117       United Arab Emirates          West & Central Asia           0         0         10        19        40        59        0
# 118       Uzbekistan                    West & Central Asia           0         0         9         8         29        27        0
# 119       Yemen                         West & Central Asia           2         0         11        28        111       154       0

# %%
## Task 1.4

query = {
    "$and":[
        {"NT":{
            "gt": 200
        }}, 
        {"LC":{
            "gt":1000
        }}
    ]
}
show(coll, query, header, spacing, keys)
# Out:
# ID        Country   EX        EW        CR        EN        VU        LRCD      DD        LC

# %%
## Task 1.5
query = {
    "$not":{"Region":"South & Southeast Asia"}, 
}
show(coll, query, header, spacing, keys)
conn.close()
